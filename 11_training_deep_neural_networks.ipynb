# %% [markdown]
# **Chapter 11 – Training Deep Neural Networks**

# %% [markdown]
# _This notebook contains all the sample code and solutions to the exercises in chapter 11._

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml3/blob/main/11_training_deep_neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml3/blob/main/11_training_deep_neural_networks.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# # Setup

# %% [markdown]
# This project requires Python 3.7 or above:

# %%
import sys

assert sys.version_info >= (3, 7)

# %% [markdown]
# And TensorFlow ≥ 2.8:

# %%
from packaging import version
import tensorflow as tf

assert version.parse(tf.__version__) >= version.parse("2.8.0")

# %% [markdown]
# As we did in previous chapters, let's define the default font sizes to make the figures prettier:

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# And let's create the `images/deep` folder (if it doesn't already exist), and define the `save_fig()` function which is used through this notebook to save the figures in high-res for the book:

# %%
from pathlib import Path

IMAGES_PATH = Path() / "images" / "deep"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# # Vanishing/Exploding Gradients Problem

# %%
# extra code – this cell generates and saves Figure 11–1

import numpy as np

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

z = np.linspace(-5, 5, 200)

plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([-5, 5], [1, 1], 'k--')
plt.plot([0, 0], [-0.2, 1.2], 'k-')
plt.plot([-5, 5], [-3/4, 7/4], 'g--')
plt.plot(z, sigmoid(z), "b-", linewidth=2,
         label=r"$\sigma(z) = \dfrac{1}{1+e^{-z}}$")
props = dict(facecolor='black', shrink=0.1)
plt.annotate('Saturating', xytext=(3.5, 0.7), xy=(5, 1), arrowprops=props,
             fontsize=14, ha="center")
plt.annotate('Saturating', xytext=(-3.5, 0.3), xy=(-5, 0), arrowprops=props,
             fontsize=14, ha="center")
plt.annotate('Linear', xytext=(2, 0.2), xy=(0, 0.5), arrowprops=props,
             fontsize=14, ha="center")
plt.grid(True)
plt.axis([-5, 5, -0.2, 1.2])
plt.xlabel("$z$")
plt.legend(loc="upper left", fontsize=16)

save_fig("sigmoid_saturation_plot")
plt.show()

# %% [markdown]
# ## Xavier and He Initialization

# %%
## 1. Zanikanie/eksplodowanie gradientów - inicjalizacja wag
#### Powinna być mozliwość wyboru funkcji inicjalizacji wag kernel_initializer w aplikacji jak i łatwość w dodawaniu nowych (elastyczna architektura)

# Inicjalizacje wag słuzące ograniczeniu nierównych gradientów
# Parametry inicjujące dla różnych funkcji aktywacji

# Inicjalizacja |  Funkcja aktywacji                |  σ2 (Rozkład normalny)
# Glorota       |  brak, tanh, logistyczna, softmax |  1/obcśr
# He            |  ReLU i jej odmiany               |  2/obcwe
# LeCuna        |  SELU                             |  1/obcwe

## Wykorzystanie inicjalizacji wag "he" dla funkcji aktywacji ReLu
dense = tf.keras.layers.Dense(50, activation="relu",
                              kernel_initializer="he_normal")

# %%
## 2 Dodatkowa opcja - inicjalizacja "he" z innym rozkładem
# Dodatkowe inicjalizacje

he_avg_init = tf.keras.initializers.VarianceScaling(scale=2., mode="fan_avg",
                                                    distribution="uniform")
dense = tf.keras.layers.Dense(50, activation="sigmoid",
                              kernel_initializer=he_avg_init)

# %% [markdown]
# ## Nonsaturating Activation Functions

# %% [markdown]
# ### Leaky ReLU

# %%
## 3. Zanikanie/eksplodowanie gradientów - Przeciekająca funkcja ReLu
#### Powinna być możliwość wyboru funkcji aktywacji jak i łatwość w dodawaniu nowych (elastyczna architektura)

# Jest to rozwiązanie dla zjawiska zwanego "śmiercią neuronów" - w którym jedynym przesyłanym przez nie sygnałem jest 0.
# Zawiera parametr alfa który określa nachylenie funkcji dla z = 0

# extra code – this cell generates and saves Figure 11–2

def leaky_relu(z, alpha):
    return np.maximum(alpha * z, z)

z = np.linspace(-5, 5, 200)
plt.plot(z, leaky_relu(z, 0.1), "b-", linewidth=2, label=r"$LeakyReLU(z) = max(\alpha z, z)$")
plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([0, 0], [-1, 3.7], 'k-')
plt.grid(True)
props = dict(facecolor='black', shrink=0.1)
plt.annotate('Leak', xytext=(-3.5, 0.5), xy=(-5, -0.3), arrowprops=props,
             fontsize=14, ha="center")
plt.xlabel("$z$")
plt.axis([-5, 5, -1, 3.7])
plt.gca().set_aspect("equal")
plt.legend()

save_fig("leaky_relu_plot")
plt.show()

# %%
leaky_relu = tf.keras.layers.LeakyReLU(alpha=0.2)  # defaults to alpha=0.3
dense = tf.keras.layers.Dense(50, activation=leaky_relu,
                              kernel_initializer="he_normal")

# %%
## 4 Można użyć klasy LeakyReLU jako osobnej warstwy - nie wpływa to na proces uczenia

model = tf.keras.models.Sequential([
    # [...]  # more layers
    tf.keras.layers.Dense(50, kernel_initializer="he_normal"),  # no activation
    tf.keras.layers.LeakyReLU(alpha=0.2),  # activation as a separate layer
    # [...]  # more layers
])

# %% [markdown]
# ### ELU

# %% [markdown]
# Implementing ELU in TensorFlow is trivial, just specify the activation function when building each layer, and use He initialization:

# %%
## 5 Zanikanie/eksplodowanie gradientów - funkcja ELU
# Funkcja aktywacji wykładniczo-liniowa
# Rozwiązany problem znikających gradientów oraz umierających neuronów
# Przyspiesza metodę gradientu prostego
# Największa wada - jest wyliczana wolniej od standardowej funkcji ReLu.

dense = tf.keras.layers.Dense(50, activation="elu",
                              kernel_initializer="he_normal")

# %% [markdown]
# ### SELU

# %% [markdown]
# By default, the SELU hyperparameters (`scale` and `alpha`) are tuned in such a way that the mean output of each neuron remains close to 0, and the standard deviation remains close to 1 (assuming the inputs are standardized with mean 0 and standard deviation 1 too, and other constraints are respected, as explained in the book). Using this activation function, even a 1,000 layer deep neural network preserves roughly mean 0 and standard deviation 1 across all layers, avoiding the exploding/vanishing gradients problem:

# %%
## 6 Zanikanie/eksplodowanie gradientów - funkcja SELU

# Skalowana funkcja aktywacji
# Aby skorzystać nalezy:
# - cechy wejściowe muszą być znormalizowane - średnia równa 0 i odchylenie standardowe równe 1
# - wagi kazdej warstwy ukrytej muszą być inicjalizowane za pomocą inicjalizacji LeCuna z rozkładem normalnym
# W interfejsie Keras oznacza to wyznaczenie parametru kernel_initializer="lecun_normal"
# - własności samonormalizacji jest charakterystyczna wyłącznie dla zwykłych prceptonów wielowarstwowych
# jeśli spróbujemy wykorzystać SELU w innych sieciach takich jak sieci rekurencyjne czy połączenia pomijające 
# to prawdopodobnie nie osiągnie lepszych rezultatów od funkcji ELU
# - nie można korzystać z technik jak regularyzacja e1, e2, max-norm, normalizacja wsadowa czy klasyczne porzucenie


# extra code – this cell generates and saves Figure 11–3

from scipy.special import erfc

# alpha and scale to self normalize with mean 0 and standard deviation 1
# (see equation 14 in the paper):
alpha_0_1 = -np.sqrt(2 / np.pi) / (erfc(1 / np.sqrt(2)) * np.exp(1 / 2) - 1)
scale_0_1 = (
    (1 - erfc(1 / np.sqrt(2)) * np.sqrt(np.e))
    * np.sqrt(2 * np.pi)
    * (
        2 * erfc(np.sqrt(2)) * np.e ** 2
        + np.pi * erfc(1 / np.sqrt(2)) ** 2 * np.e
        - 2 * (2 + np.pi) * erfc(1 / np.sqrt(2)) * np.sqrt(np.e)
        + np.pi
        + 2
    ) ** (-1 / 2)
)

def elu(z, alpha=1):
    return np.where(z < 0, alpha * (np.exp(z) - 1), z)

def selu(z, scale=scale_0_1, alpha=alpha_0_1):
    return scale * elu(z, alpha)

z = np.linspace(-5, 5, 200)
plt.plot(z, elu(z), "b-", linewidth=2, label=r"ELU$_\alpha(z) = \alpha (e^z - 1)$ if $z < 0$, else $z$")
plt.plot(z, selu(z), "r--", linewidth=2, label=r"SELU$(z) = 1.05 \, $ELU$_{1.67}(z)$")
plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([-5, 5], [-1, -1], 'k:', linewidth=2)
plt.plot([-5, 5], [-1.758, -1.758], 'k:', linewidth=2)
plt.plot([0, 0], [-2.2, 3.2], 'k-')
plt.grid(True)
plt.axis([-5, 5, -2.2, 3.2])
plt.xlabel("$z$")
plt.gca().set_aspect("equal")
plt.legend()

save_fig("elu_selu_plot")
plt.show()

# %% [markdown]
# Using SELU is straightforward:

# %%
dense = tf.keras.layers.Dense(50, activation="selu",
                              kernel_initializer="lecun_normal")

# %% [markdown]
# **Extra material – an example of a self-regularized network using SELU**
#
# Let's create a neural net for Fashion MNIST with 100 hidden layers, using the SELU activation function:

# %%
## 7 Użycie funkcji SELU dla problemu obrazków

# Stworzenie modelu
# Dodanie warstw
tf.random.set_seed(42)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[28, 28]))
for layer in range(100):
    model.add(tf.keras.layers.Dense(100, activation="selu",
                                    kernel_initializer="lecun_normal"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %%
# Kompilacja modelu
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %% [markdown]
# Now let's train it. Do not forget to scale the inputs to mean 0 and standard deviation 1:

# %%
# Podział danych
fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]
X_train, X_valid, X_test = X_train / 255, X_valid / 255, X_test / 255

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
pixel_means = X_train.mean(axis=0, keepdims=True)
pixel_stds = X_train.std(axis=0, keepdims=True)
X_train_scaled = (X_train - pixel_means) / pixel_stds
X_valid_scaled = (X_valid - pixel_means) / pixel_stds
X_test_scaled = (X_test - pixel_means) / pixel_stds

# %%
# Trening
history = model.fit(X_train_scaled, y_train, epochs=5,
                    validation_data=(X_valid_scaled, y_valid))

# Epoch 1/5 1719/1719 [==============================] - 13s 7ms/step - loss: 1.3735 - accuracy: 0.4548 - val_loss: 0.9599 - val_accuracy: 0.6444
# - loss: To jest wartość funkcji straty (loss function) obliczona na danych treningowych po zakończeniu tej epoki. Funkcja straty mierzy, jak dobrze model radzi sobie z przewidywaniem wyników na danych, na których się uczył. 
# Niższa wartość straty jest lepsza - Trend pożądany: Powinna spadać

# - accuracy: To jest metryka dokładności (accuracy) obliczona na danych treningowych po zakończeniu tej epoki. Mierzy ona odsetek poprawnych przewidywań modelu. 0.4548: Oznacza to, że model poprawnie sklasyfikował około 45.48% próbek z zestawu treningowego.
# Trend pożądany: Powinna rosnąć

# - val_loss: To jest wartość funkcji straty obliczona na danych walidacyjnych po zakończeniu tej epoki. Te dane nie były używane do treningu modelu, więc ta wartość jest lepszym wskaźnikiem tego, jak dobrze model uogólnia się na niewidzialne dane.
# Trend pożądany: Powinna spadać w trakcie treningu, przynajmniej przez pewien czas. (Powinien podążać za trendami treningowymi)
# Jeśli val_loss zaczyna rosnąć (podczas gdy loss nadal spada lub pozostaje niska), oznacza to, że model zaczyna się przetrenowywać – 
# zbyt dobrze zapamiętuje dane treningowe i traci zdolność do uogólniania na nowe dane.
# Idealny punkt zatrzymania: Często najlepszy model to ten, który osiągnął najniższą wartość val_loss, zanim zaczęła ona rosnąć.

# - val_accuracy: To jest metryka dokładności obliczona na danych walidacyjnych po zakończeniu tej epoki. Podobnie jak val_loss, jest to kluczowa metryka do oceny uogólniania modelu.
# Trend pożądany: Powinna rosnąć w trakcie treningu, przynajmniej przez pewien czas. (Powinien podążać za trendami treningowymi)
# Wskazanie na przetrenowanie (overfitting): Jeśli val_accuracy zaczyna spadać (podczas gdy accuracy nadal rośnie), jest to również sygnał przetrenowania.

# W tym konkretnym przypadku można zauważyć, że val_accuracy (64.44%) jest znacznie wyższa niż accuracy (45.48%). 
# Może to sugerować, że problem zanikających/eksplodujących gradientów nadal występuje, 
# a model nie uczy się efektywnie na danych treningowych, lub że w danych treningowych występuje problem, 
# który nie występuje w danych walidacyjnych, lub też, 
# że w tym konkretnym przykładzie trening jeszcze się nie ustabilizował i model jest na wczesnym etapie nauki.
# Out:
# Epoch 1/5
# 1719/1719 [==============================] - 16s 8ms/step - loss: 1.3392 - accuracy: 0.4794 - val_loss: 1.1905 - val_accuracy: 0.5276
# Epoch 2/5
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.8846 - accuracy: 0.6525 - val_loss: 0.7659 - val_accuracy: 0.7052
# Epoch 3/5
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.7521 - accuracy: 0.6964 - val_loss: 0.7095 - val_accuracy: 0.7374
# Epoch 4/5
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.6946 - accuracy: 0.7361 - val_loss: 0.6730 - val_accuracy: 0.7538
# Epoch 5/5
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.6177 - accuracy: 0.7728 - val_loss: 0.6113 - val_accuracy: 0.7832

# %% [markdown]
# The network managed to learn, despite how deep it is. Now look at what happens if we try to use the ReLU activation function instead:

# %%
## 8 Użycie funkcji ReLu dla problemu obrazków

tf.random.set_seed(42)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[28, 28]))
for layer in range(100):
    model.add(tf.keras.layers.Dense(100, activation="relu",
                                    kernel_initializer="he_normal"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
history = model.fit(X_train_scaled, y_train, epochs=5,
                    validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/5
# 1719/1719 [==============================] - 12s 6ms/step - loss: 1.8610 - accuracy: 0.2939 - val_loss: 1.4504 - val_accuracy: 0.4720
# Epoch 2/5
# 1719/1719 [==============================] - 10s 6ms/step - loss: 1.4512 - accuracy: 0.4297 - val_loss: 1.0440 - val_accuracy: 0.6154
# Epoch 3/5
# 1719/1719 [==============================] - 10s 6ms/step - loss: 1.2040 - accuracy: 0.5119 - val_loss: 0.9417 - val_accuracy: 0.6418
# Epoch 4/5
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.9418 - accuracy: 0.6342 - val_loss: 0.8987 - val_accuracy: 0.6554
# Epoch 5/5
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.8871 - accuracy: 0.6627 - val_loss: 1.0696 - val_accuracy: 0.6588

# %% [markdown]
# Not great at all, we suffered from the vanishing/exploding gradients problem.

# %% [markdown]
# ### GELU, Swish and Mish

# %%
## 9 Zanikanie/eksplodowanie gradientów - funkcje GELU, SWISH, MISH

# GELU
# Skomplikowany kształt, w kadym punkcie występuje krzywizna - dua skuteczność w skomplikowanych zadaniach
# Jest bardziej wymagająca obliczeniowo

# SWISH
# - niektóre badania twierdzą ze jest lepsza, inne ze gorsza od GELU

# MISH
# Zasadniczo uzyskiwała lpesze wyniki od pozostałych
# 
# Zatem jaką funkcję aktywacji należy zastosować w warstwach ukrytych Twoich sieci
# głębokich? Liczba przebiegów może się różnić w poszczególnych sieciach, ale generalnie
# kolejność wygląda następująco: funkcja SELU > ELU > przeciekająca ReLU (wraz
# z odmianami) > ReLU > tangensa hiperbolicznego > logistyczna. 

# Jeżeli dana sieć nie podlega samonormalizacji, to funkcja ELU może dawać lepsze rezultaty niż funkcja
# SELU (gdyż funkcja SELU nie jest gładka w punkcie z = 0). 

# Jeśli bardziej zależy Ci na szybkości, możesz wybrać przeciekającą funkcję ReLU. Jeżeli nie masz ochoty dostrajać kolejnego parametru, możesz użyć domyślnych wartości α zdefiniowanych
# w interfejsie Keras (np. 0,3 dla przeciekającej funkcji ReLU). Z kolei jeśli masz nadmiar czasu i mocy obliczeniowej, możesz ocenić skuteczność innych funkcji aktywacji
# za pomocą sprawdzianu krzyżowego, zwłaszcza funkcji RReLU, jeśli Twoja sieć ulega przetrenowaniu, lub PReLU dla dużych zbiorów uczących. 
# Pamiętaj, że (obecnie) ReLU jest najczęściej wykorzystywaną funkcją aktywacji, dlatego wiele bibliotek i akceleratorów sprzętowych zostało zoptymalizowanych pod nią, a zatem jeśli szybkość stanowi
# priorytet, to najlepszym wyborem może być funkcja ReLU.

# extra code – this cell generates and saves Figure 11–4

def swish(z, beta=1):
    return z * sigmoid(beta * z)

def approx_gelu(z):
    return swish(z, beta=1.702)

def softplus(z):
    return np.log(1 + np.exp(z))

def mish(z):
    return z * np.tanh(softplus(z))

z = np.linspace(-4, 2, 200)

beta = 0.6
plt.plot(z, approx_gelu(z), "b-", linewidth=2,
         label=r"GELU$(z) = z\,\Phi(z)$")
plt.plot(z, swish(z), "r--", linewidth=2,
         label=r"Swish$(z) = z\,\sigma(z)$")
plt.plot(z, swish(z, beta), "r:", linewidth=2,
         label=fr"Swish$_{{\beta={beta}}}(z)=z\,\sigma({beta}\,z)$")
plt.plot(z, mish(z), "g:", linewidth=3,
         label=fr"Mish$(z) = z\,\tanh($softplus$(z))$")
plt.plot([-4, 2], [0, 0], 'k-')
plt.plot([0, 0], [-2.2, 3.2], 'k-')
plt.grid(True)
plt.axis([-4, 2, -1, 2])
plt.gca().set_aspect("equal")
plt.xlabel("$z$")
plt.legend(loc="upper left")

save_fig("gelu_swish_mish_plot")
plt.show()

# %% [markdown]
# # Batch Normalization

# %%
## 10 Zanikanie/eksplodowanie gradientów - Normalizacja wsadowa

#### Powinna być możliwość elastycznego dodawania warstw do modelu, z założeniem że w przyszłości może być niezbęne dodanie całkiem nowych warstw

# Stosowanie inicjalizacji He wraz z funkcją ReLu lub jej odmianami moze zredukować problem z gradientami
# ale nie gwarantuje ochrony przed nimi po upływie czasu.
# Normalizacja wsadowa pozwala modelowi określić optymalną skalę i średnią danych wejściowych dla kazdej warstwy.
# W wielu przypadkach po umieszczeniu warstwy BN (BatchNormalization - normalizacja wsadowa) na samym początku sieci neuronowej
# nie trzeba standaryzować zestawu danych uczących (uzywać StandardScaler'a)

# Problemy przy testowaniu:
# - być może chcemy czasami uzyskiwać prognozy dla pojedynczych przykładów, a nie całych ich
# grup — w takiej sytuacji nie ma możliwości obliczenia średniej i odchylenia standardowego każdego
# wejścia
# Rozwiązanie: zaczekanie do końca trenigu, a następnie przepuszczenie całego zestawu przez sieć neuronową i obliczenie średniej oraz odchylenia standardowego kazdego wejścia w warstwie BN.

# W skrócie - jest to metoda zajebista ale dodaje poziom skomplikowania oraz spowalnia model
# Istnieje mozliwość scalenia warstwy BN z warstwą wcześniejszą, co pozwala uniknąć częściowo spowolnienia działania modelu
# Dokonujemy tego poprzez zaktualizowanie wag i obciążeń tej wcześniejszej warstwy tak, że będzie ona bezpośrednio generowała wyniki o odpowiedniej skali i odpowiednim przesunięciu

# extra code - clear the name counters and set the random seed
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
## 11 Implementacja normalizacji wsadowej - BatchNormalization

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(300, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  batch_normalization (Batch  (None, 784)               3136
#  Normalization)
#
#  dense (Dense)               (None, 300)               235500
#
#  batch_normalization_1 (Bat  (None, 300)               1200
#  chNormalization)
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  batch_normalization_2 (Bat  (None, 100)               400
#  chNormalization)
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 271346 (1.04 MB)
# Trainable params: 268978 (1.03 MB)
# Non-trainable params: 2368 (9.25 KB)
# _________________________________________________________________

# %%
## 12 Parametry pierwszej warstwy BN
# dwa są modyfikowalne, dwa nie
# Twórcy algorytmu BN sugerują zeby warstwę normalizacji wsadowej umieszczać raczej przed funkcją aktywacji - co do tego nie ma pewności, dobrze jest samemu sprawdzić 
# - zeby móc dodawać warstwy BN przed funkcją aktywacji, trzeba uzunąć funckje aktywacji z warstw ukrytych i wstawić je jako osobne warstwy po warstwach normalizacji
# - warstwa BN zawiera po jednym parametrze przesunięcia na kazde wejście - dlatego możesz usunąć człon obciążenia z 
# warstwy poprzedzającej (wystarczy przekazać use_bias=False podczas tworzenia tej warstwy)

# BatchNormalization zawiera sporo parametrów do strojenia - zazwyczaj domyślne powinny wystarczyć ale sporadycznie moze być niezbędne modyfikowanie następujących
# - momentum, dobra wartość jest bliska 1, np 0,9; 0,99; 0,999 - im większy zestaw danych i mnijesza grupa, tym więcej dziewiątek
# - axis, za jego pomocą wyznaczamy oś, która ma zostać znormalizowana. Jego domyślna wartość to -1, co oznacza, że normalizowana będzie ostatnia oś (za pomocą
# średnich i odchyleń standardowych obliczanych ze wszystkich pozostałych osi). Jeżeli grupa wejściowa jest dwuwymiarowa (tzn. jej wymiary to [rozmiar grupy, cechy]), oznacza to, że każda cecha
# wejściowa będzie normalizowana na podstawie średniej i odchylenia standardowego obliczonych
# ze wszystkich przykładów tworzących grupę. Na przykład pierwsza warstwa BN w powyższym listingu
# będzie niezależnie normalizować (a także skalować i przesuwać) każdą z 784 cech wejściowych.
# Jeżeli przeniesiemy warstwę normalizacji wsadowej przed warstwę Flatten, to grupy wejściowe będą
# trójwymiarowe ([rozmiar grupy, wysokość, szerokość]), zatem warstwa BN będzie obliczać 28 średnich
# i tyle samo odchyleń standardowych (po jednym parametrze każdego typu na kolumnę pikseli
# obliczonym dla wszystkich przykładów tworzących grupę i dla wszystkich rzędów w kolumnie)
# i znormalizuje wszystkie piksele w danej kolumnie za pomocą tej samej średniej i tego samego odchylenia standardowego. Występować będzie także 28 parametrów skalowania i 28 parametrów przesunięcia. Gdybyśmy chcieli przetwarzać każdy z 784 pikseli niezależenie od pozostałych, powinniśmy wyznaczyć axis=[1, 2]

[(var.name, var.trainable) for var in model.layers[1].variables]
# Out:
# [('batch_normalization/gamma:0', True),
#  ('batch_normalization/beta:0', True),
#  ('batch_normalization/moving_mean:0', False),
#  ('batch_normalization/moving_variance:0', False)]

# %%
## 13 Odpalenie normalizacji wsadowej dla problemu obrazków

# extra code – just show that the model works! 😊
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd",
              metrics=["accuracy"])
model.fit(X_train, y_train, epochs=2, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5551 - accuracy: 0.8070 - val_loss: 0.3982 - val_accuracy: 0.8532
# Epoch 2/2
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4050 - accuracy: 0.8574 - val_loss: 0.3603 - val_accuracy: 0.8644

# %% [markdown]
# Sometimes applying BN before the activation function works better (there's a debate on this topic). Moreover, the layer before a `BatchNormalization` layer does not need to have bias terms, since the `BatchNormalization` layer some as well, it would be a waste of parameters, so you can set `use_bias=False` when creating those layers:

# %%
## 14 Odpalenie normalizacji wsadowej za funkcją aktywacji - dla problemu obrazków

# extra code - clear the name counters and set the random seed
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(300, kernel_initializer="he_normal", use_bias=False),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.Dense(100, kernel_initializer="he_normal", use_bias=False),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
# extra code – just show that the model works! 😊
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd",
              metrics=["accuracy"])
model.fit(X_train, y_train, epochs=2, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 [==============================] - 2s 887us/step - loss: 0.6058 - accuracy: 0.7974 - val_loss: 0.4334 - val_accuracy: 0.8420
# Epoch 2/2
# 1719/1719 [==============================] - 1s 841us/step - loss: 0.4271 - accuracy: 0.8508 - val_loss: 0.3713 - val_accuracy: 0.8650

# %% [markdown]
# ## Gradient Clipping

# %% [markdown]
# All `tf.keras.optimizers` accept `clipnorm` or `clipvalue` arguments:

# %%
## 15 Obcinanie gradientu - 
# zazwyczaj stosowane w rekurencyjnych sieciach neuronowych, gdzie normalizacja wsadowa jest skomplikowana

#### Zrobić porównanie w kodzie dla normalizacji wsadowej i obcinania gradientu

optimizer = tf.keras.optimizers.SGD(clipvalue=1.0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer)

# optymalizator obcina kazdą składową wektora gradientów do wartości z przedziału -1 do 1
# wartość progowa jest hiperparametrem który mozna dostroić
# jeśli nie chcesz zeby obcinanie gradientu zmieniło kierunek wektora, uzyj argumentu "clipnorm", wtedy gradient zostanie obcięty, gdy jego norma e2 jest większa od wyznaczonej wartości progowej
# jeśli zauwazysz ze gradienty eksplodują w trakcie uczenia, wypróbuj obcinanie gradientów za pomocą wartości lub normy dla róznych wartości progowych i sprawdź które rozwiązanie sprawdza się najlepiej w przypadku zestawu walidacyjnego
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
optimizer = tf.keras.optimizers.SGD(clipnorm=1.0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
model.fit(X_train, y_train, epochs=2, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3762 - val_loss: 0.3580
# Epoch 2/2
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3538 - val_loss: 0.3461

# %% [markdown]
# ## Reusing Pretrained Layers

# %% [markdown]
# ### Reusing a Keras model

# %% [markdown]
# Let's split the fashion MNIST training set in two:
# * `X_train_A`: all images of all items except for T-shirts/tops and pullovers (classes 0 and 2).
# * `X_train_B`: a much smaller training set of just the first 200 images of T-shirts/tops and pullovers.
#
# The validation set and the test set are also split this way, but without restricting the number of images.
#
# We will train a model on set A (classification task with 8 classes), and try to reuse it to tackle set B (binary classification). We hope to transfer a little bit of knowledge from task A to task B, since classes in set A (trousers, dresses, coats, sandals, shirts, sneakers, bags, and ankle boots) are somewhat similar to classes in set B (T-shirts/tops and pullovers). However, since we are using `Dense` layers, only patterns that occur at the same location can be reused (in contrast, convolutional layers will transfer much better, since learned patterns can be detected anywhere on the image, as we will see in the chapter 14).

# %%
## 16 Uczenie transferowe - najbardziej skuteczne w głębokich sieciach splotowych - zazwyczaj przed rozpoczęciem uczenia duzej sieci GNS bez próby uprzedniego poszukania jakiejś istniejącej dostosowanej do realizowanego zadania nie jest dobrym pomysłem
# Zakladając ze mamy dostęp do głebokiej sieci neuronowej która została wyuczona do klasyfikowania obrazów pomiędzy 100 róznych kategorii, jak zwierzęta, rośliny, pojazdy i przedmioty, a chcemy wytrenować sieć do klasyfikowania określonych typów pojazdów:
# - zazwyczaj zastąpić pierwszą warstwę wyjściową modelu (za pewne inna liczba wyjść)
# - podobnie z górnymi warstwami - pewnie nie będą przydatne ze względu na inne cechy szczegółowe zadania
# - na początku warto zamrozić wszystkie warstwy (zablokować moliwość modyfikowania wag przez algorytm gradientu prostego) a potem wytrenować model i zobaczyć jak się spisuje
# - następnie odmrozić jedną/dwie górne warstwy i ponownie wytrwnować
# - im więcej danych uczących tym ięcej warstw mozna odmrozić
# - warto tez zmnijeszyć współczynnik uczenia podczas odmrazania warstw
# - Jeżeli ciągle masz problem z uzyskaniem dobrej wydajności i dysponujesz niewielką ilością danych, spróbuj porzucić co najmniej jedną górną warstwę ukrytą i ponownie zamroź pozostałe warstwy ukryte. Powtarzaj tę czynność aż do uzyskania właściwej liczby wielokrotnie używanych warstw. Jeżeli masz dużo danych uczących, możesz zastępować, a nawet dodawać kolejne warstwy ukryte zamiast je usuwać,

#### Modele w aplikacji powinny być tak zapisywane i dostępne żeby można było łatwo wykonać uczenie transferowe

# extra code – split Fashion MNIST into tasks A and B, then train and save
#              model A to "my_model_A".

## 17 Uczenie transferowe w Keras, przykład z obrazkami ubrań

## 18 Zbudowanie i wytrenowanie modelu dla 8 klas (zamiast porzednich 10)

pos_class_id = class_names.index("Pullover")
neg_class_id = class_names.index("T-shirt/top")

def split_dataset(X, y):
    y_for_B = (y == pos_class_id) | (y == neg_class_id)
    y_A = y[~y_for_B]
    y_B = (y[y_for_B] == pos_class_id).astype(np.float32)
    old_class_ids = list(set(range(10)) - set([neg_class_id, pos_class_id]))
    for old_class_id, new_class_id in zip(old_class_ids, range(8)):
        y_A[y_A == old_class_id] = new_class_id  # reorder class ids for A
    return ((X[~y_for_B], y_A), (X[y_for_B], y_B))

(X_train_A, y_train_A), (X_train_B, y_train_B) = split_dataset(X_train, y_train)
(X_valid_A, y_valid_A), (X_valid_B, y_valid_B) = split_dataset(X_valid, y_valid)
(X_test_A, y_test_A), (X_test_B, y_test_B) = split_dataset(X_test, y_test)
X_train_B = X_train_B[:200]
y_train_B = y_train_B[:200]

tf.random.set_seed(42)

model_A = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(8, activation="softmax")
])

model_A.compile(loss="sparse_categorical_crossentropy",
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
                metrics=["accuracy"])
history = model_A.fit(X_train_A, y_train_A, epochs=20,
                      validation_data=(X_valid_A, y_valid_A))

## 19 Zapisanie modelu
model_A.save("my_model_A.keras")
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Epoch 1/20
# 1376/1376 [==============================] - 1s 689us/step - loss: 1.2281 - accuracy: 0.6328 - val_loss: 0.7416 - val_accuracy: 0.7744
# Epoch 2/20
# 1376/1376 [==============================] - 1s 637us/step - loss: 0.6332 - accuracy: 0.8042 - val_loss: 0.5310 - val_accuracy: 0.8320
# Epoch 3/20
# 1376/1376 [==============================] - 1s 637us/step - loss: 0.4940 - accuracy: 0.8469 - val_loss: 0.4454 - val_accuracy: 0.8556
# Epoch 4/20
# 1376/1376 [==============================] - 1s 642us/step - loss: 0.4257 - accuracy: 0.8628 - val_loss: 0.3972 - val_accuracy: 0.8679
# Epoch 5/20
# 1376/1376 [==============================] - 1s 632us/step - loss: 0.3850 - accuracy: 0.8730 - val_loss: 0.3666 - val_accuracy: 0.8749
# Epoch 6/20
# 1376/1376 [==============================] - 1s 639us/step - loss: 0.3579 - accuracy: 0.8790 - val_loss: 0.3462 - val_accuracy: 0.8792
# Epoch 7/20
# 1376/1376 [==============================] - 1s 650us/step - loss: 0.3390 - accuracy: 0.8844 - val_loss: 0.3313 - val_accuracy: 0.8819
# Epoch 8/20
# 1376/1376 [==============================] - 1s 640us/step - loss: 0.3242 - accuracy: 0.8884 - val_loss: 0.3228 - val_accuracy: 0.8882
# Epoch 9/20
# 1376/1376 [==============================] - 1s 659us/step - loss: 0.3130 - accuracy: 0.8925 - val_loss: 0.3114 - val_accuracy: 0.8894
# Epoch 10/20
# 1376/1376 [==============================] - 1s 644us/step - loss: 0.3032 - accuracy: 0.8958 - val_loss: 0.3056 - val_accuracy: 0.8915
# Epoch 11/20
# 1376/1376 [==============================] - 1s 636us/step - loss: 0.2948 - accuracy: 0.8986 - val_loss: 0.3004 - val_accuracy: 0.8940
# Epoch 12/20
# 1376/1376 [==============================] - 1s 636us/step - loss: 0.2880 - accuracy: 0.9014 - val_loss: 0.2965 - val_accuracy: 0.8962
# Epoch 13/20
# 1376/1376 [==============================] - 1s 632us/step - loss: 0.2824 - accuracy: 0.9031 - val_loss: 0.2907 - val_accuracy: 0.8967
# Epoch 14/20
# 1376/1376 [==============================] - 1s 638us/step - loss: 0.2766 - accuracy: 0.9051 - val_loss: 0.2818 - val_accuracy: 0.8980
# Epoch 15/20
# 1376/1376 [==============================] - 1s 631us/step - loss: 0.2719 - accuracy: 0.9066 - val_loss: 0.2782 - val_accuracy: 0.8995
# Epoch 16/20
# 1376/1376 [==============================] - 1s 658us/step - loss: 0.2672 - accuracy: 0.9079 - val_loss: 0.2756 - val_accuracy: 0.9005
# Epoch 17/20
# 1376/1376 [==============================] - 1s 634us/step - loss: 0.2630 - accuracy: 0.9092 - val_loss: 0.2703 - val_accuracy: 0.9020
# Epoch 18/20
# 1376/1376 [==============================] - 1s 631us/step - loss: 0.2587 - accuracy: 0.9114 - val_loss: 0.2691 - val_accuracy: 0.9050
# Epoch 19/20
# 1376/1376 [==============================] - 1s 634us/step - loss: 0.2554 - accuracy: 0.9131 - val_loss: 0.2667 - val_accuracy: 0.9030
# Epoch 20/20
# 1376/1376 [==============================] - 1s 638us/step - loss: 0.2517 - accuracy: 0.9148 - val_loss: 0.2661 - val_accuracy: 0.9067

# %%
## 20 Trenowanie modelu B bez reużywania modelu A

# extra code – train and evaluate model B, without reusing model A

tf.random.set_seed(42)
model_B = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model_B.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
                metrics=["accuracy"])
history = model_B.fit(X_train_B, y_train_B, epochs=20,
                      validation_data=(X_valid_B, y_valid_B))
model_B.evaluate(X_test_B, y_test_B)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Epoch 1/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.7584 - accuracy: 0.5550 - val_loss: 0.7519 - val_accuracy: 0.5163
# Epoch 2/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7099 - accuracy: 0.5550 - val_loss: 0.7134 - val_accuracy: 0.5163
# Epoch 3/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6774 - accuracy: 0.5600 - val_loss: 0.6867 - val_accuracy: 0.5183
# Epoch 4/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6529 - accuracy: 0.5600 - val_loss: 0.6638 - val_accuracy: 0.5183
# Epoch 5/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6328 - accuracy: 0.5600 - val_loss: 0.6427 - val_accuracy: 0.5282
# Epoch 6/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6140 - accuracy: 0.5800 - val_loss: 0.6243 - val_accuracy: 0.5648
# Epoch 7/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5971 - accuracy: 0.6250 - val_loss: 0.6076 - val_accuracy: 0.6409
# Epoch 8/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5827 - accuracy: 0.7000 - val_loss: 0.5936 - val_accuracy: 0.7003
# Epoch 9/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5690 - accuracy: 0.7700 - val_loss: 0.5814 - val_accuracy: 0.7438
# Epoch 10/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5570 - accuracy: 0.7850 - val_loss: 0.5696 - val_accuracy: 0.7705
# Epoch 11/20
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5451 - accuracy: 0.8100 - val_loss: 0.5582 - val_accuracy: 0.8022
# Epoch 12/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5336 - accuracy: 0.8150 - val_loss: 0.5467 - val_accuracy: 0.8378
# Epoch 13/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5221 - accuracy: 0.8450 - val_loss: 0.5366 - val_accuracy: 0.8457
# Epoch 14/20
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5119 - accuracy: 0.8600 - val_loss: 0.5266 - val_accuracy: 0.8546
# Epoch 15/20
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5019 - accuracy: 0.8600 - val_loss: 0.5163 - val_accuracy: 0.8764
# Epoch 16/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4915 - accuracy: 0.8800 - val_loss: 0.5066 - val_accuracy: 0.8793
# Epoch 17/20
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4817 - accuracy: 0.8800 - val_loss: 0.4971 - val_accuracy: 0.8843
# Epoch 18/20
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4723 - accuracy: 0.8850 - val_loss: 0.4870 - val_accuracy: 0.9050
# Epoch 19/20
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4622 - accuracy: 0.9050 - val_loss: 0.4779 - val_accuracy: 0.9120
# Epoch 20/20
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4534 - accuracy: 0.9150 - val_loss: 0.4692 - val_accuracy: 0.9169
# 63/63 [==============================] - 0s 459us/step - loss: 0.4787 - accuracy: 0.9040
# [0.47867560386657715, 0.9039999842643738]

# %% [markdown]
# Model B reaches 91.85% accuracy on the test set. Now let's try reusing the pretrained model A.

# %%
## 21 Tworzenie nowego modelu na podstawie istniejącego

model_A = tf.keras.models.load_model("my_model_A.keras") # Załadowanie wcześniej wytrenowanego modelu - cały model, włącznie z jego architekturą, wagami i konfiguracją treningu, jest odzyskiwany
model_B_on_A = tf.keras.Sequential(model_A.layers[:-1]) # Stworzenie nowego modelu, pobiera wszystkie warstwy z model_A z wyjątkiem ostatniej (wyjściowej)
model_B_on_A.add(tf.keras.layers.Dense(1, activation="sigmoid")) # Ta linia dodaje nową warstwę wyjściową z jednym neuronem i funkcją aktywacji sigmoid do model_B_on_A.
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %% [markdown]
# Note that `model_B_on_A` and `model_A` actually share layers now, so when we train one, it will update both models. If we want to avoid that, we need to build `model_B_on_A` on top of a *clone* of `model_A`:

# %%
tf.random.set_seed(42)  # extra code – ensure reproducibility

# %%
## 22 Klonowanie modelu przed korzystaniem z jego warstw oraz kopiowanie wag

model_A_clone = tf.keras.models.clone_model(model_A) # klonowanie struktury sieci
model_A_clone.set_weights(model_A.get_weights()) # kopiowanie wag - bez tego wagi zostałyby losowo zainicjowane

# %%
# extra code – creating model_B_on_A just like in the previous cell
model_B_on_A = tf.keras.Sequential(model_A_clone.layers[:-1])
model_B_on_A.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# %%
## 23 Ponieważ nowa warstwa wyjściowa została zainicjowana losowo będzie popełniać duze błędy - w ciągu kilku pierwszych epok
# Mozna tego uniknąć, zamrazając te warstwy przez kilka pierwszych epok, dzięki temu damy czas nowej warstwie na poznanie rozsądnych wartości wag

for layer in model_B_on_A.layers[:-1]:
    layer.trainable = False

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)

## 24 Nalezy zawsze kompilować model po zamrozeniu lub rozmrozeniu warstw
model_B_on_A.compile(loss="binary_crossentropy", optimizer=optimizer,
                     metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
## 25 Trenowanie modelu przez kilka epok, następnie rozmroenie warstw, kompilacja i ponowny trening

# tutaj zostało przetestowane wiele róznych kofiguracji !!!
# zastosowana technika: "torturowanie danych a do uzyskania odpowiedzi"

history = model_B_on_A.fit(X_train_B, y_train_B, epochs=4,
                           validation_data=(X_valid_B, y_valid_B))

for layer in model_B_on_A.layers[:-1]:
    layer.trainable = True

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model_B_on_A.compile(loss="binary_crossentropy", optimizer=optimizer,
                     metrics=["accuracy"])
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=16,
                           validation_data=(X_valid_B, y_valid_B))
# Out:
# Epoch 1/4
# 7/7 [==============================] - 0s 13ms/step - loss: 1.9629 - accuracy: 0.4450 - val_loss: 1.3622 - val_accuracy: 0.4847
# Epoch 2/4
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1493 - accuracy: 0.4450 - val_loss: 0.7925 - val_accuracy: 0.4906
# Epoch 3/4
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7008 - accuracy: 0.4900 - val_loss: 0.6030 - val_accuracy: 0.6815
# Epoch 4/4
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5722 - accuracy: 0.7450 - val_loss: 0.5793 - val_accuracy: 0.7409
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Epoch 1/16
# 7/7 [==============================] - 0s 13ms/step - loss: 0.5334 - accuracy: 0.8050 - val_loss: 0.5296 - val_accuracy: 0.7913
# Epoch 2/16
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4838 - accuracy: 0.8500 - val_loss: 0.4845 - val_accuracy: 0.8408
# Epoch 3/16
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4407 - accuracy: 0.8900 - val_loss: 0.4560 - val_accuracy: 0.8625
# Epoch 4/16
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4043 - accuracy: 0.9000 - val_loss: 0.4255 - val_accuracy: 0.8872
# Epoch 5/16
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3771 - accuracy: 0.9200 - val_loss: 0.4006 - val_accuracy: 0.9041
# Epoch 6/16
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3550 - accuracy: 0.9350 - val_loss: 0.3801 - val_accuracy: 0.9110
# Epoch 7/16
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3350 - accuracy: 0.9400 - val_loss: 0.3667 - val_accuracy: 0.9041
# Epoch 8/16
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3242 - accuracy: 0.9350 - val_loss: 0.3502 - val_accuracy: 0.9169
# Epoch 9/16
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3059 - accuracy: 0.9400 - val_loss: 0.3369 - val_accuracy: 0.9288
# Epoch 10/16
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2942 - accuracy: 0.9400 - val_loss: 0.3260 - val_accuracy: 0.9308
# Epoch 11/16
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2841 - accuracy: 0.9450 - val_loss: 0.3153 - val_accuracy: 0.9337
# Epoch 12/16
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2743 - accuracy: 0.9450 - val_loss: 0.3062 - val_accuracy: 0.9347
# Epoch 13/16
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2643 - accuracy: 0.9450 - val_loss: 0.2984 - val_accuracy: 0.9327
# Epoch 14/16
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2581 - accuracy: 0.9450 - val_loss: 0.2916 - val_accuracy: 0.9357
# Epoch 15/16
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2515 - accuracy: 0.9450 - val_loss: 0.2846 - val_accuracy: 0.9377
# Epoch 16/16
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2441 - accuracy: 0.9450 - val_loss: 0.2782 - val_accuracy: 0.9397

# %% [markdown]
# So, what's the final verdict?

# %%
model_B_on_A.evaluate(X_test_B, y_test_B)
# Out:
# 63/63 [==============================] - 0s 438us/step - loss: 0.2853 - accuracy: 0.9270
# [0.2853328585624695, 0.9269999861717224]

# %% [markdown]
# Great! We got a bit of transfer: the model's accuracy went up 2 percentage points, from 91.85% to 93.85%. This means the error rate dropped by almost 25%:

# %%
1 - (100 - 93.85) / (100 - 91.85)
# Out:
# 0.24539877300613477

# %% [markdown]
# # Faster Optimizers

# %%
## 26 Co do tej pory zostało omówione w kontekście przyspieszenia procesu uczenia
# - wybranie odpowiedniej strategii inicjalizowania wag połączeń
# - zastosowanie dobrej funkcji aktywacji
# - wprowadzenie normalizacji wsadowej
# - wielokrotne stosowanie składnków juz istniejącej sieci (za pomocą dodatkowego zadania lub uczenia nienadzorowanego)

## 27 Optymalizatory - kolejny element przyspieszający proces uczenia

#### Powinna być możliwość doboru optymalizatorów

# extra code – a little function to test an optimizer on Fashion MNIST

def build_model(seed=42):
    tf.random.set_seed(seed)
    return tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=[28, 28]),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

def build_and_train_model(optimizer):
    model = build_model()
    model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
                  metrics=["accuracy"])
    return model.fit(X_train, y_train, epochs=10,
                     validation_data=(X_valid, y_valid))

# %%
#### Przykład patternu na budowę modelu w aplikacji

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
history_sgd = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 1s 704us/step - loss: 1.4533 - accuracy: 0.5392 - val_loss: 0.9247 - val_accuracy: 0.6944
# Epoch 2/10
# 1719/1719 [==============================] - 1s 656us/step - loss: 0.8207 - accuracy: 0.7183 - val_loss: 0.7114 - val_accuracy: 0.7580
# Epoch 3/10
# 1719/1719 [==============================] - 1s 656us/step - loss: 0.6788 - accuracy: 0.7705 - val_loss: 0.6145 - val_accuracy: 0.7922
# Epoch 4/10
# 1719/1719 [==============================] - 1s 654us/step - loss: 0.6069 - accuracy: 0.7959 - val_loss: 0.5639 - val_accuracy: 0.8072
# Epoch 5/10
# 1719/1719 [==============================] - 1s 647us/step - loss: 0.5634 - accuracy: 0.8072 - val_loss: 0.5328 - val_accuracy: 0.8168
# Epoch 6/10
# 1719/1719 [==============================] - 1s 656us/step - loss: 0.5341 - accuracy: 0.8169 - val_loss: 0.5159 - val_accuracy: 0.8172
# Epoch 7/10
# 1719/1719 [==============================] - 1s 661us/step - loss: 0.5130 - accuracy: 0.8227 - val_loss: 0.4921 - val_accuracy: 0.8244
# Epoch 8/10
# 1719/1719 [==============================] - 1s 678us/step - loss: 0.4967 - accuracy: 0.8280 - val_loss: 0.4819 - val_accuracy: 0.8276
# Epoch 9/10
# 1719/1719 [==============================] - 1s 654us/step - loss: 0.4832 - accuracy: 0.8333 - val_loss: 0.4692 - val_accuracy: 0.8294
# Epoch 10/10
# 1719/1719 [==============================] - 1s 652us/step - loss: 0.4716 - accuracy: 0.8357 - val_loss: 0.4581 - val_accuracy: 0.8330

# %% [markdown]
# ## Momentum optimization

# %%
## 28 Optymalizator momentum
# Zawiera nowy hiperparametr momentum - domyślna wartość 0.9 prawie zawsze będzie lepsza niż gradient prosty

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
history_momentum = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 1s 703us/step - loss: 0.6981 - accuracy: 0.7608 - val_loss: 0.4992 - val_accuracy: 0.8266
# Epoch 2/10
# 1719/1719 [==============================] - 1s 734us/step - loss: 0.4703 - accuracy: 0.8355 - val_loss: 0.4530 - val_accuracy: 0.8396
# Epoch 3/10
# 1719/1719 [==============================] - 1s 681us/step - loss: 0.4252 - accuracy: 0.8499 - val_loss: 0.4237 - val_accuracy: 0.8532
# Epoch 4/10
# 1719/1719 [==============================] - 1s 697us/step - loss: 0.3988 - accuracy: 0.8594 - val_loss: 0.3845 - val_accuracy: 0.8612
# Epoch 5/10
# 1719/1719 [==============================] - 1s 689us/step - loss: 0.3771 - accuracy: 0.8653 - val_loss: 0.3676 - val_accuracy: 0.8696
# Epoch 6/10
# 1719/1719 [==============================] - 1s 686us/step - loss: 0.3633 - accuracy: 0.8705 - val_loss: 0.3671 - val_accuracy: 0.8688
# Epoch 7/10
# 1719/1719 [==============================] - 1s 719us/step - loss: 0.3480 - accuracy: 0.8748 - val_loss: 0.3678 - val_accuracy: 0.8692
# Epoch 8/10
# 1719/1719 [==============================] - 1s 684us/step - loss: 0.3395 - accuracy: 0.8767 - val_loss: 0.3505 - val_accuracy: 0.8746
# Epoch 9/10
# 1719/1719 [==============================] - 1s 680us/step - loss: 0.3296 - accuracy: 0.8810 - val_loss: 0.3643 - val_accuracy: 0.8672
# Epoch 10/10
# 1719/1719 [==============================] - 1s 677us/step - loss: 0.3190 - accuracy: 0.8848 - val_loss: 0.3748 - val_accuracy: 0.8690

# %% [markdown]
# ## Nesterov Accelerated Gradient

# %%
## 29 W omawianym przykładzie algorytm Nesterova lepszy od zwykłego momentum

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9,
                                    nesterov=True)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
history_nesterov = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 1s 779us/step - loss: 0.6841 - accuracy: 0.7681 - val_loss: 0.4972 - val_accuracy: 0.8198
# Epoch 2/10
# 1719/1719 [==============================] - 1s 738us/step - loss: 0.4584 - accuracy: 0.8386 - val_loss: 0.4274 - val_accuracy: 0.8442
# Epoch 3/10
# 1719/1719 [==============================] - 1s 751us/step - loss: 0.4161 - accuracy: 0.8527 - val_loss: 0.4091 - val_accuracy: 0.8538
# Epoch 4/10
# 1719/1719 [==============================] - 1s 731us/step - loss: 0.3913 - accuracy: 0.8620 - val_loss: 0.3859 - val_accuracy: 0.8612
# Epoch 5/10
# 1719/1719 [==============================] - 1s 751us/step - loss: 0.3716 - accuracy: 0.8688 - val_loss: 0.3752 - val_accuracy: 0.8642
# Epoch 6/10
# 1719/1719 [==============================] - 1s 737us/step - loss: 0.3576 - accuracy: 0.8718 - val_loss: 0.3892 - val_accuracy: 0.8648
# Epoch 7/10
# 1719/1719 [==============================] - 1s 743us/step - loss: 0.3425 - accuracy: 0.8769 - val_loss: 0.3765 - val_accuracy: 0.8618
# Epoch 8/10
# 1719/1719 [==============================] - 1s 737us/step - loss: 0.3322 - accuracy: 0.8793 - val_loss: 0.3699 - val_accuracy: 0.8678
# Epoch 9/10
# 1719/1719 [==============================] - 1s 759us/step - loss: 0.3225 - accuracy: 0.8844 - val_loss: 0.3622 - val_accuracy: 0.8680
# Epoch 10/10
# 1719/1719 [==============================] - 1s 740us/step - loss: 0.3119 - accuracy: 0.8872 - val_loss: 0.3755 - val_accuracy: 0.8666

# %% [markdown]
# ## AdaGrad

# %%
## 30 Adaptacyjny współczynnik uczenia 
# Częst osprawdza się dobrze w przypadku prstych problemów kwadratowych, ale potrafi się zatrzymać zbyt wcześnie  podczas uczenia sieci neuronowych - współczynnik uczenia moze zostać zredukowany w takim stopniu ze algorytm skończy pracę przed oiągnięciem minimum globalnego.

optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.001)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adagrad` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adagrad`.

# %%
history_adagrad = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 1s 753us/step - loss: 1.0495 - accuracy: 0.6708 - val_loss: 0.6974 - val_accuracy: 0.7750
# Epoch 2/10
# 1719/1719 [==============================] - 1s 721us/step - loss: 0.6498 - accuracy: 0.7830 - val_loss: 0.5929 - val_accuracy: 0.8040
# Epoch 3/10
# 1719/1719 [==============================] - 1s 720us/step - loss: 0.5793 - accuracy: 0.8068 - val_loss: 0.5446 - val_accuracy: 0.8202
# Epoch 4/10
# 1719/1719 [==============================] - 1s 735us/step - loss: 0.5417 - accuracy: 0.8180 - val_loss: 0.5181 - val_accuracy: 0.8270
# Epoch 5/10
# 1719/1719 [==============================] - 1s 771us/step - loss: 0.5172 - accuracy: 0.8250 - val_loss: 0.4982 - val_accuracy: 0.8318
# Epoch 6/10
# 1719/1719 [==============================] - 1s 740us/step - loss: 0.4997 - accuracy: 0.8297 - val_loss: 0.4863 - val_accuracy: 0.8348
# Epoch 7/10
# 1719/1719 [==============================] - 1s 752us/step - loss: 0.4864 - accuracy: 0.8337 - val_loss: 0.4728 - val_accuracy: 0.8378
# Epoch 8/10
# 1719/1719 [==============================] - 1s 736us/step - loss: 0.4760 - accuracy: 0.8363 - val_loss: 0.4645 - val_accuracy: 0.8390
# Epoch 9/10
# 1719/1719 [==============================] - 1s 775us/step - loss: 0.4670 - accuracy: 0.8397 - val_loss: 0.4578 - val_accuracy: 0.8376
# Epoch 10/10
# 1719/1719 [==============================] - 1s 789us/step - loss: 0.4591 - accuracy: 0.8421 - val_loss: 0.4512 - val_accuracy: 0.8416

# %% [markdown]
# ## RMSProp

# %%
## 31 W tym algorytmie problem przedwczesnego skończenia pracy został rozwiązany
# w przypadku prostych problemów radzi sobie gorzej niz AdaGrad
# mamy dodatkowy hiperparametr

optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.

# %%
history_rmsprop = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 832us/step - loss: 0.5120 - accuracy: 0.8153 - val_loss: 0.4696 - val_accuracy: 0.8128
# Epoch 2/10
# 1719/1719 [==============================] - 1s 753us/step - loss: 0.3913 - accuracy: 0.8598 - val_loss: 0.4203 - val_accuracy: 0.8446
# Epoch 3/10
# 1719/1719 [==============================] - 1s 749us/step - loss: 0.3659 - accuracy: 0.8683 - val_loss: 0.4094 - val_accuracy: 0.8632
# Epoch 4/10
# 1719/1719 [==============================] - 1s 746us/step - loss: 0.3617 - accuracy: 0.8733 - val_loss: 0.3703 - val_accuracy: 0.8658
# Epoch 5/10
# 1719/1719 [==============================] - 1s 748us/step - loss: 0.3566 - accuracy: 0.8763 - val_loss: 0.3576 - val_accuracy: 0.8758
# Epoch 6/10
# 1719/1719 [==============================] - 1s 751us/step - loss: 0.3506 - accuracy: 0.8782 - val_loss: 0.4380 - val_accuracy: 0.8642
# Epoch 7/10
# 1719/1719 [==============================] - 1s 749us/step - loss: 0.3490 - accuracy: 0.8791 - val_loss: 0.4161 - val_accuracy: 0.8694
# Epoch 8/10
# 1719/1719 [==============================] - 1s 771us/step - loss: 0.3436 - accuracy: 0.8816 - val_loss: 0.4334 - val_accuracy: 0.8644
# Epoch 9/10
# 1719/1719 [==============================] - 1s 748us/step - loss: 0.3444 - accuracy: 0.8831 - val_loss: 0.4173 - val_accuracy: 0.8750
# Epoch 10/10
# 1719/1719 [==============================] - 1s 747us/step - loss: 0.3379 - accuracy: 0.8854 - val_loss: 0.4253 - val_accuracy: 0.8686

# %% [markdown]
# ## Adam Optimization

# %%
## 32 Ten optymalizator łączy zalety obu powyszych algorytmów i jest on (i jego odmiany) na dzień dzisiejszy pierwszym wyborem
# mamy dwa nowe hiperparametry
# - beta_1
# - beta_2

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9,
                                     beta_2=0.999)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
history_adam = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4956 - accuracy: 0.8243 - val_loss: 0.4194 - val_accuracy: 0.8380
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3717 - accuracy: 0.8645 - val_loss: 0.3837 - val_accuracy: 0.8512
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3386 - accuracy: 0.8755 - val_loss: 0.3497 - val_accuracy: 0.8754
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3162 - accuracy: 0.8828 - val_loss: 0.3428 - val_accuracy: 0.8752
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2971 - accuracy: 0.8890 - val_loss: 0.3192 - val_accuracy: 0.8806
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2813 - accuracy: 0.8944 - val_loss: 0.3435 - val_accuracy: 0.8754
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2711 - accuracy: 0.8984 - val_loss: 0.3437 - val_accuracy: 0.8810
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2597 - accuracy: 0.9018 - val_loss: 0.3176 - val_accuracy: 0.8870
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2507 - accuracy: 0.9054 - val_loss: 0.3718 - val_accuracy: 0.8690
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2426 - accuracy: 0.9084 - val_loss: 0.3558 - val_accuracy: 0.8828

# %% [markdown]
# **Adamax Optimization**

# %%
## 33 Adamax - Warto go wypróbować jeśli optymalizator Adam będzie miał problemy z zadaniem 

optimizer = tf.keras.optimizers.Adamax(learning_rate=0.001, beta_1=0.9,
                                       beta_2=0.999)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.

# %%
history_adamax = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 947us/step - loss: 0.5478 - accuracy: 0.8103 - val_loss: 0.4476 - val_accuracy: 0.8366
# Epoch 2/10
# 1719/1719 [==============================] - 1s 826us/step - loss: 0.3989 - accuracy: 0.8575 - val_loss: 0.3915 - val_accuracy: 0.8536
# Epoch 3/10
# 1719/1719 [==============================] - 1s 839us/step - loss: 0.3616 - accuracy: 0.8703 - val_loss: 0.3680 - val_accuracy: 0.8692
# Epoch 4/10
# 1719/1719 [==============================] - 1s 804us/step - loss: 0.3364 - accuracy: 0.8790 - val_loss: 0.3480 - val_accuracy: 0.8740
# Epoch 5/10
# 1719/1719 [==============================] - 1s 805us/step - loss: 0.3164 - accuracy: 0.8848 - val_loss: 0.3287 - val_accuracy: 0.8796
# Epoch 6/10
# 1719/1719 [==============================] - 1s 803us/step - loss: 0.3014 - accuracy: 0.8895 - val_loss: 0.3324 - val_accuracy: 0.8824
# Epoch 7/10
# 1719/1719 [==============================] - 1s 800us/step - loss: 0.2879 - accuracy: 0.8939 - val_loss: 0.3416 - val_accuracy: 0.8750
# Epoch 8/10
# 1719/1719 [==============================] - 1s 794us/step - loss: 0.2785 - accuracy: 0.8961 - val_loss: 0.3116 - val_accuracy: 0.8886
# Epoch 9/10
# 1719/1719 [==============================] - 1s 839us/step - loss: 0.2681 - accuracy: 0.9007 - val_loss: 0.3454 - val_accuracy: 0.8732
# Epoch 10/10
# 1719/1719 [==============================] - 1s 852us/step - loss: 0.2574 - accuracy: 0.9046 - val_loss: 0.3486 - val_accuracy: 0.8742

# %% [markdown]
# **Nadam Optimization**

# %%
## 34 Jak powyzej - warto go wypróbować jeśli optymalizator Adam będzie miał problemy z zadaniem

optimizer = tf.keras.optimizers.Nadam(learning_rate=0.001, beta_1=0.9,
                                      beta_2=0.999)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Nadam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Nadam`.

# %%
history_nadam = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4818 - accuracy: 0.8297 - val_loss: 0.4140 - val_accuracy: 0.8468
# Epoch 2/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3638 - accuracy: 0.8676 - val_loss: 0.3842 - val_accuracy: 0.8532
# Epoch 3/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3307 - accuracy: 0.8769 - val_loss: 0.3570 - val_accuracy: 0.8724
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3092 - accuracy: 0.8862 - val_loss: 0.3225 - val_accuracy: 0.8814
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2915 - accuracy: 0.8914 - val_loss: 0.3218 - val_accuracy: 0.8794
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2778 - accuracy: 0.8961 - val_loss: 0.3510 - val_accuracy: 0.8796
# Epoch 7/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2662 - accuracy: 0.9000 - val_loss: 0.3557 - val_accuracy: 0.8836
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2551 - accuracy: 0.9030 - val_loss: 0.3286 - val_accuracy: 0.8814
# Epoch 9/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2442 - accuracy: 0.9075 - val_loss: 0.3676 - val_accuracy: 0.8760
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2351 - accuracy: 0.9107 - val_loss: 0.3509 - val_accuracy: 0.8798

# %% [markdown]
# **AdamW Optimization**

# %% [markdown]
# Note: Since TF 1.12, `AdamW` is no longer experimental. It is available at `tf.keras.optimizers.AdamW` instead of `tf.keras.optimizers.experimental.AdamW`.

# %%
## 35 Jak u dwóch powyzej - warto go wypróbować jeśli optymalizator Adam będzie miał problemy z zadaniem

optimizer = tf.keras.optimizers.AdamW(weight_decay=1e-5, learning_rate=0.001,
                                      beta_1=0.9, beta_2=0.999)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.AdamW` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.AdamW`.

# %%
history_adamw = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5019 - accuracy: 0.8207 - val_loss: 0.4234 - val_accuracy: 0.8386
# Epoch 2/10
# 1719/1719 [==============================] - 2s 941us/step - loss: 0.3768 - accuracy: 0.8627 - val_loss: 0.3794 - val_accuracy: 0.8572
# Epoch 3/10
# 1719/1719 [==============================] - 2s 981us/step - loss: 0.3405 - accuracy: 0.8740 - val_loss: 0.3473 - val_accuracy: 0.8692
# Epoch 4/10
# 1719/1719 [==============================] - 2s 988us/step - loss: 0.3168 - accuracy: 0.8830 - val_loss: 0.3336 - val_accuracy: 0.8776
# Epoch 5/10
# 1719/1719 [==============================] - 2s 925us/step - loss: 0.2990 - accuracy: 0.8897 - val_loss: 0.3282 - val_accuracy: 0.8738
# Epoch 6/10
# 1719/1719 [==============================] - 2s 972us/step - loss: 0.2834 - accuracy: 0.8943 - val_loss: 0.3333 - val_accuracy: 0.8794
# Epoch 7/10
# 1719/1719 [==============================] - 2s 954us/step - loss: 0.2741 - accuracy: 0.8964 - val_loss: 0.3742 - val_accuracy: 0.8700
# Epoch 8/10
# 1719/1719 [==============================] - 2s 951us/step - loss: 0.2613 - accuracy: 0.9010 - val_loss: 0.3157 - val_accuracy: 0.8900
# Epoch 9/10
# 1719/1719 [==============================] - 2s 969us/step - loss: 0.2528 - accuracy: 0.9047 - val_loss: 0.3869 - val_accuracy: 0.8680
# Epoch 10/10
# 1719/1719 [==============================] - 2s 990us/step - loss: 0.2457 - accuracy: 0.9067 - val_loss: 0.3530 - val_accuracy: 0.8726

# %%
## 36 Adaptacyjne metody optymalizacji jak Adam często sprawdzają się znakomicie, jednak czasami mogą nie radzić sobie z pewnymi zbiorami danych - wtedy warto wrócić do zwykłego algorytmu Nesterova

# porównanie optymalizatorów

# Klasa                               | Szybkość uzyskiwania zbieżności | Stopień uzyskanej zbieżności
# SGD                                 |                *                | ***
# SGD(momentum=…)                     |                **               | ***
# SGD(momentum=…, nesterov=True)      |                **               | ***
# Adagrad                             |                ***              | * (zatrzymuje się zbyt wcześnie)
# RMSprop                             |                ***              | ** lub ***
# Adam                                |                ***              | ** lub ***
# Nadam                               |                ***              | ** lub ***
# AdaMax                              |                ***              | ** lub ***

# extra code – visualize the learning curves of all the optimizers

for loss in ("loss", "val_loss"):
    plt.figure(figsize=(12, 8))
    opt_names = "SGD Momentum Nesterov AdaGrad RMSProp Adam Adamax Nadam AdamW"
    for history, opt_name in zip((history_sgd, history_momentum, history_nesterov,
                                  history_adagrad, history_rmsprop, history_adam,
                                  history_adamax, history_nadam, history_adamw),
                                 opt_names.split()):
        plt.plot(history.history[loss], label=f"{opt_name}", linewidth=3)

    plt.grid()
    plt.xlabel("Epochs")
    plt.ylabel({"loss": "Training loss", "val_loss": "Validation loss"}[loss])
    plt.legend(loc="upper left")
    plt.axis([0, 9, 0.1, 0.7])
    plt.show()

# %% [markdown]
# ## Learning Rate Scheduling

# %% [markdown]
# ### Power Scheduling

# %% [markdown]
# ```python
# learning_rate = initial_learning_rate / (1 + step / decay_steps)**power
# ```
#
# Keras uses `power = 1`.

# %% [markdown]
# **Note**: Optimizers used to have a `decay` argument for this, but it was deprecated. You must use the schedulers in `tf.keras.optimizers.schedules` instead.

# %%
## 37 Współczynnik uczenia
# - za duzy współczynnik uczenia - algorytm stanie się rozbiezny
# - zbyt mały - algorytm uzyska zbiezność ale zajmie to mnóstwo czasu
# - przy niewielkim zawyżeniu współczynnik będzie na początku radził sobie dobrze ale ostatecznie będzie ciągle przeskakiwał optimum i nigdy nie znajdzie minimum
# - przy ograniczonych zasobach trzeba czasami przerwać naukę przed osiągnięciem zbiezności

# Harmonogramowanie potęgowe

lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    initial_learning_rate=0.01, # Początkowa szybkość uczenia się wynosi 0.01
    decay_steps=10_000, # Parametr ten wraz z decay_rate kontroluje, jak szybko spada szybkość uczenia się. Określa skalę czasu dla spadku. W tym przypadku spadek jest rozłożony na 10 000 kroków
    decay_rate=1.0, # Współczynnik, który wpływa na szybkość spadku. Większa wartość oznacza szybszy spadek. Formuła dla InverseTimeDecay to: initial_learning_rate / (1 + decay_rate * step / decay_steps)
    staircase=False # Oznacza to, że szybkość uczenia się będzie zmieniać się płynnie. Gdyby było True, spadałaby w dyskretnych krokach.
)
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %% [markdown]
# The `InverseTimeDecay` scheduler uses `learning_rate = initial_learning_rate / (1 + decay_rate * step / decay_steps)`. If you set `staircase=True`, then it replaces `step / decay_step` with `floor(step / decay_step)`.

# %%
history_power_scheduling = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 1s 706us/step - loss: 0.6925 - accuracy: 0.7629 - val_loss: 0.4858 - val_accuracy: 0.8322
# Epoch 2/10
# 1719/1719 [==============================] - 1s 649us/step - loss: 0.4700 - accuracy: 0.8346 - val_loss: 0.4516 - val_accuracy: 0.8418
# Epoch 3/10
# 1719/1719 [==============================] - 1s 660us/step - loss: 0.4261 - accuracy: 0.8495 - val_loss: 0.4144 - val_accuracy: 0.8560
# Epoch 4/10
# 1719/1719 [==============================] - 1s 643us/step - loss: 0.4040 - accuracy: 0.8581 - val_loss: 0.3917 - val_accuracy: 0.8614
# Epoch 5/10
# 1719/1719 [==============================] - 1s 641us/step - loss: 0.3856 - accuracy: 0.8642 - val_loss: 0.3841 - val_accuracy: 0.8618
# Epoch 6/10
# 1719/1719 [==============================] - 1s 642us/step - loss: 0.3717 - accuracy: 0.8677 - val_loss: 0.3888 - val_accuracy: 0.8626
# Epoch 7/10
# 1719/1719 [==============================] - 1s 669us/step - loss: 0.3619 - accuracy: 0.8707 - val_loss: 0.3685 - val_accuracy: 0.8682
# Epoch 8/10
# 1719/1719 [==============================] - 1s 647us/step - loss: 0.3528 - accuracy: 0.8744 - val_loss: 0.3700 - val_accuracy: 0.8644
# Epoch 9/10
# 1719/1719 [==============================] - 1s 652us/step - loss: 0.3450 - accuracy: 0.8777 - val_loss: 0.3551 - val_accuracy: 0.8716
# Epoch 10/10
# 1719/1719 [==============================] - 1s 647us/step - loss: 0.3377 - accuracy: 0.8805 - val_loss: 0.3553 - val_accuracy: 0.8678

# %%
# extra code – this cell plots power scheduling with staircase=True or False

initial_learning_rate = 0.01
decay_rate = 1.0
decay_steps = 10_000

steps = np.arange(100_000)
lrs = initial_learning_rate / (1 + decay_rate * steps / decay_steps)
lrs2 = initial_learning_rate / (1 + decay_rate * np.floor(steps / decay_steps))

plt.plot(steps, lrs,  "-", label="staircase=False")
plt.plot(steps, lrs2,  "-", label="staircase=True")
plt.axis([0, steps.max(), 0, 0.0105])
plt.xlabel("Step")
plt.ylabel("Learning Rate")
plt.title("Power Scheduling", fontsize=14)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exponential Scheduling

# %% [markdown]
# ```python
# learning_rate = initial_learning_rate * decay_rate ** (step / decay_steps)
# ```

# %%
## 38 Harmonogramowanie wykładnicze

#### Istnieją jeszcze inne typy harmonogramowania - warto tutaj dodać owartą furtkę w aplikacji
# 1cycle
# stałoprzecinkowe
# wydajnościowe

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=20_000,
    decay_rate=0.1,
    staircase=False
)
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
history_exponential_scheduling = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 1s 694us/step - loss: 0.6800 - accuracy: 0.7677 - val_loss: 0.4956 - val_accuracy: 0.8282
# Epoch 2/10
# 1719/1719 [==============================] - 1s 660us/step - loss: 0.4741 - accuracy: 0.8341 - val_loss: 0.4407 - val_accuracy: 0.8438
# Epoch 3/10
# 1719/1719 [==============================] - 1s 675us/step - loss: 0.4281 - accuracy: 0.8469 - val_loss: 0.4162 - val_accuracy: 0.8536
# Epoch 4/10
# 1719/1719 [==============================] - 1s 702us/step - loss: 0.4056 - accuracy: 0.8569 - val_loss: 0.3897 - val_accuracy: 0.8620
# Epoch 5/10
# 1719/1719 [==============================] - 1s 656us/step - loss: 0.3882 - accuracy: 0.8627 - val_loss: 0.3829 - val_accuracy: 0.8614
# Epoch 6/10
# 1719/1719 [==============================] - 1s 657us/step - loss: 0.3757 - accuracy: 0.8669 - val_loss: 0.3865 - val_accuracy: 0.8600
# Epoch 7/10
# 1719/1719 [==============================] - 1s 658us/step - loss: 0.3672 - accuracy: 0.8692 - val_loss: 0.3733 - val_accuracy: 0.8632
# Epoch 8/10
# 1719/1719 [==============================] - 1s 660us/step - loss: 0.3601 - accuracy: 0.8718 - val_loss: 0.3737 - val_accuracy: 0.8622
# Epoch 9/10
# 1719/1719 [==============================] - 1s 656us/step - loss: 0.3542 - accuracy: 0.8744 - val_loss: 0.3664 - val_accuracy: 0.8624
# Epoch 10/10
# 1719/1719 [==============================] - 1s 699us/step - loss: 0.3494 - accuracy: 0.8757 - val_loss: 0.3626 - val_accuracy: 0.8662

# %%
# extra code – this cell plots exponential scheduling

initial_learning_rate = 0.01
decay_rate = 0.1
decay_steps = 20_000

steps = np.arange(100_000)
lrs = initial_learning_rate * decay_rate ** (steps / decay_steps)
lrs2 = initial_learning_rate * decay_rate ** np.floor(steps / decay_steps)

plt.plot(steps, lrs,  "-", label="staircase=False")
plt.plot(steps, lrs2,  "-", label="staircase=True")
plt.axis([0, steps.max(), 0, 0.0105])
plt.xlabel("Step")
plt.ylabel("Learning Rate")
plt.title("Exponential Scheduling", fontsize=14)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Keras also provides a `LearningRateScheduler` callback class that lets you define your own scheduling function. Let's see how you could use it to implement exponential decay. Note that in this case the learning rate only changes at each epoch, not at each step:

# %%
## 39 Harmonogramowanie wykładnicze - implementacja 

def exponential_decay_fn(epoch):
    return 0.01 * 0.1 ** (epoch / 20)

# %%
#### Definiowanie różnych parametrów dla harmonogramowania wykładniczego - bez hardkodowania parametrów

def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(lr0=0.01, s=20)

# %%
# extra code – build and compile a model for Fashion MNIST

tf.random.set_seed(42)
model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
n_epochs = 20

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 1s 693us/step - loss: 0.6735 - accuracy: 0.7698 - val_loss: 0.4802 - val_accuracy: 0.8320 - lr: 0.0100
# Epoch 2/20
# 1719/1719 [==============================] - 1s 647us/step - loss: 0.4635 - accuracy: 0.8357 - val_loss: 0.4534 - val_accuracy: 0.8360 - lr: 0.0089
# Epoch 3/20
# 1719/1719 [==============================] - 1s 671us/step - loss: 0.4187 - accuracy: 0.8506 - val_loss: 0.4154 - val_accuracy: 0.8532 - lr: 0.0079
# Epoch 4/20
# 1719/1719 [==============================] - 1s 657us/step - loss: 0.3949 - accuracy: 0.8591 - val_loss: 0.3896 - val_accuracy: 0.8628 - lr: 0.0071
# Epoch 5/20
# 1719/1719 [==============================] - 1s 654us/step - loss: 0.3769 - accuracy: 0.8660 - val_loss: 0.3797 - val_accuracy: 0.8624 - lr: 0.0063
# Epoch 6/20
# 1719/1719 [==============================] - 1s 689us/step - loss: 0.3632 - accuracy: 0.8700 - val_loss: 0.3797 - val_accuracy: 0.8660 - lr: 0.0056
# Epoch 7/20
# 1719/1719 [==============================] - 1s 624us/step - loss: 0.3534 - accuracy: 0.8724 - val_loss: 0.3687 - val_accuracy: 0.8648 - lr: 0.0050
# Epoch 8/20
# 1719/1719 [==============================] - 1s 616us/step - loss: 0.3447 - accuracy: 0.8760 - val_loss: 0.3672 - val_accuracy: 0.8654 - lr: 0.0045
# Epoch 9/20
# 1719/1719 [==============================] - 1s 638us/step - loss: 0.3373 - accuracy: 0.8795 - val_loss: 0.3551 - val_accuracy: 0.8698 - lr: 0.0040
# Epoch 10/20
# 1719/1719 [==============================] - 1s 654us/step - loss: 0.3305 - accuracy: 0.8818 - val_loss: 0.3609 - val_accuracy: 0.8702 - lr: 0.0035
# Epoch 11/20
# 1719/1719 [==============================] - 1s 645us/step - loss: 0.3251 - accuracy: 0.8838 - val_loss: 0.3495 - val_accuracy: 0.8728 - lr: 0.0032
# Epoch 12/20
# 1719/1719 [==============================] - 1s 658us/step - loss: 0.3201 - accuracy: 0.8846 - val_loss: 0.3548 - val_accuracy: 0.8704 - lr: 0.0028
# Epoch 13/20
# 1719/1719 [==============================] - 1s 657us/step - loss: 0.3163 - accuracy: 0.8876 - val_loss: 0.3435 - val_accuracy: 0.8754 - lr: 0.0025
# Epoch 14/20
# 1719/1719 [==============================] - 1s 669us/step - loss: 0.3123 - accuracy: 0.8890 - val_loss: 0.3443 - val_accuracy: 0.8796 - lr: 0.0022
# Epoch 15/20
# 1719/1719 [==============================] - 1s 661us/step - loss: 0.3092 - accuracy: 0.8905 - val_loss: 0.3434 - val_accuracy: 0.8784 - lr: 0.0020
# Epoch 16/20
# 1719/1719 [==============================] - 1s 643us/step - loss: 0.3061 - accuracy: 0.8904 - val_loss: 0.3368 - val_accuracy: 0.8802 - lr: 0.0018
# Epoch 17/20
# 1719/1719 [==============================] - 1s 643us/step - loss: 0.3037 - accuracy: 0.8920 - val_loss: 0.3383 - val_accuracy: 0.8764 - lr: 0.0016
# Epoch 18/20
# 1719/1719 [==============================] - 1s 653us/step - loss: 0.3015 - accuracy: 0.8924 - val_loss: 0.3382 - val_accuracy: 0.8772 - lr: 0.0014
# Epoch 19/20
# 1719/1719 [==============================] - 1s 648us/step - loss: 0.2994 - accuracy: 0.8923 - val_loss: 0.3341 - val_accuracy: 0.8786 - lr: 0.0013
# Epoch 20/20
# 1719/1719 [==============================] - 1s 669us/step - loss: 0.2977 - accuracy: 0.8939 - val_loss: 0.3356 - val_accuracy: 0.8778 - lr: 0.0011

# %%
## 40 Po zakończeniu uczenia history.history["lr"] da dostęp do listy współczynników wykorzystanych podczas uczenia

# %% [markdown]
# Alternatively, the schedule function can take the current learning rate as a second argument:

# %%
def exponential_decay_fn(epoch, lr):
    return lr * 0.1 ** (1 / 20)


# Podczas zapisywania modelu zostają wraz z nim zapisane również jego optymalizator i współczynnik uczenia. 
# Oznacza to, że w tej nowej funkcji harmonogramowania wystarczy wczytać wytrenowany
# model i kontynuować uczenie w przerwanym miejscu. Niestety przestaje to być takie proste w przypadku korzystania z argumentu epoch i jego wartość zawsze zostaje wyzerowana w momencie
# wywołania metody fit(). Gdyby kontynuować uczenie modelu od miejsca przerwania, doprowadziłoby to do bardzo dużych wartości współczynnika uczenia i prawdopodobnie zaszkodziłoby wagom
# modelu. Jednym z rozwiązań jest własnoręczne wyznaczenie argumentu initial_epoch w metodzie
# fit(), dzięki czemu parametr epoch będzie miał właściwą wartość.

# %% [markdown]
# **Extra material**: if you want to use a custom scheduling function that updates the learning rate at each iteration rather than at each epoch, you can write your own callback class like this:

# %%
## 41 Niestandardowa funkcja planowania, która aktualizuje szybkość uczenia się w każdej iteracji, a nie w każdej epoce

K = tf.keras.backend

class ExponentialDecay(tf.keras.callbacks.Callback):
    def __init__(self, n_steps=40_000):
        super().__init__()
        self.n_steps = n_steps

    def on_batch_begin(self, batch, logs=None):
        # Note: the `batch` argument is reset at each epoch
        lr = self.model.optimizer.learning_rate.numpy()
        new_learning_rate = lr * 0.1 ** (1 / self.n_steps)
        self.model.optimizer.learning_rate = new_learning_rate

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = self.model.optimizer.learning_rate.numpy()

# %%
lr0 = 0.01
model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
import math

batch_size = 32
n_steps = n_epochs * math.ceil(len(X_train) / batch_size)
exp_decay = ExponentialDecay(n_steps)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[exp_decay])
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 2s 800us/step - loss: 0.6972 - accuracy: 0.7585 - val_loss: 0.5040 - val_accuracy: 0.8220 - lr: 0.0089
# Epoch 2/20
# 1719/1719 [==============================] - 1s 768us/step - loss: 0.4714 - accuracy: 0.8359 - val_loss: 0.4461 - val_accuracy: 0.8374 - lr: 0.0079
# Epoch 3/20
# 1719/1719 [==============================] - 1s 742us/step - loss: 0.4226 - accuracy: 0.8505 - val_loss: 0.4130 - val_accuracy: 0.8508 - lr: 0.0071
# Epoch 4/20
# 1719/1719 [==============================] - 1s 743us/step - loss: 0.3988 - accuracy: 0.8595 - val_loss: 0.3901 - val_accuracy: 0.8556 - lr: 0.0063
# Epoch 5/20
# 1719/1719 [==============================] - 1s 737us/step - loss: 0.3791 - accuracy: 0.8652 - val_loss: 0.3821 - val_accuracy: 0.8624 - lr: 0.0056
# Epoch 6/20
# 1719/1719 [==============================] - 1s 735us/step - loss: 0.3645 - accuracy: 0.8707 - val_loss: 0.3895 - val_accuracy: 0.8614 - lr: 0.0050
# Epoch 7/20
# 1719/1719 [==============================] - 1s 734us/step - loss: 0.3540 - accuracy: 0.8741 - val_loss: 0.3680 - val_accuracy: 0.8662 - lr: 0.0045
# Epoch 8/20
# 1719/1719 [==============================] - 1s 730us/step - loss: 0.3448 - accuracy: 0.8774 - val_loss: 0.3676 - val_accuracy: 0.8632 - lr: 0.0040
# Epoch 9/20
# 1719/1719 [==============================] - 1s 729us/step - loss: 0.3373 - accuracy: 0.8796 - val_loss: 0.3555 - val_accuracy: 0.8684 - lr: 0.0035
# Epoch 10/20
# 1719/1719 [==============================] - 1s 768us/step - loss: 0.3302 - accuracy: 0.8818 - val_loss: 0.3558 - val_accuracy: 0.8666 - lr: 0.0032
# Epoch 11/20
# 1719/1719 [==============================] - 1s 793us/step - loss: 0.3245 - accuracy: 0.8847 - val_loss: 0.3551 - val_accuracy: 0.8710 - lr: 0.0028
# Epoch 12/20
# 1719/1719 [==============================] - 1s 771us/step - loss: 0.3195 - accuracy: 0.8851 - val_loss: 0.3524 - val_accuracy: 0.8688 - lr: 0.0025
# Epoch 13/20
# 1719/1719 [==============================] - 1s 782us/step - loss: 0.3153 - accuracy: 0.8880 - val_loss: 0.3414 - val_accuracy: 0.8742 - lr: 0.0022
# Epoch 14/20
# 1719/1719 [==============================] - 1s 768us/step - loss: 0.3118 - accuracy: 0.8888 - val_loss: 0.3452 - val_accuracy: 0.8758 - lr: 0.0020
# Epoch 15/20
# 1719/1719 [==============================] - 1s 755us/step - loss: 0.3082 - accuracy: 0.8896 - val_loss: 0.3456 - val_accuracy: 0.8748 - lr: 0.0018
# Epoch 16/20
# 1719/1719 [==============================] - 1s 754us/step - loss: 0.3052 - accuracy: 0.8908 - val_loss: 0.3392 - val_accuracy: 0.8732 - lr: 0.0016
# Epoch 17/20
# 1719/1719 [==============================] - 1s 745us/step - loss: 0.3027 - accuracy: 0.8910 - val_loss: 0.3410 - val_accuracy: 0.8754 - lr: 0.0014
# Epoch 18/20
# 1719/1719 [==============================] - 1s 742us/step - loss: 0.3004 - accuracy: 0.8928 - val_loss: 0.3387 - val_accuracy: 0.8760 - lr: 0.0013
# Epoch 19/20
# 1719/1719 [==============================] - 1s 734us/step - loss: 0.2983 - accuracy: 0.8924 - val_loss: 0.3378 - val_accuracy: 0.8796 - lr: 0.0011
# Epoch 20/20
# 1719/1719 [==============================] - 1s 736us/step - loss: 0.2964 - accuracy: 0.8934 - val_loss: 0.3374 - val_accuracy: 0.8782 - lr: 1.0000e-03

# %% [markdown]
# ### Piecewise Constant Scheduling

# %%
## 42 Harmonogramowanie stałoprzecinkowe

lr_schedule = tf.keras.optimizers.schedules.PiecewiseConstantDecay(
    boundaries = [50_000 * n_epochs // batch_size, 80_000 * n_epochs // batch_size] ,
    values=[0.01, 0.005, 0.001]
)
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
history_piecewise_scheduling = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 1s 769us/step - loss: 0.7052 - accuracy: 0.7596 - val_loss: 0.4904 - val_accuracy: 0.8300
# Epoch 2/10
# 1719/1719 [==============================] - 1s 722us/step - loss: 0.4673 - accuracy: 0.8356 - val_loss: 0.4540 - val_accuracy: 0.8398
# Epoch 3/10
# 1719/1719 [==============================] - 1s 711us/step - loss: 0.4198 - accuracy: 0.8502 - val_loss: 0.4204 - val_accuracy: 0.8538
# Epoch 4/10
# 1719/1719 [==============================] - 1s 731us/step - loss: 0.3951 - accuracy: 0.8591 - val_loss: 0.3842 - val_accuracy: 0.8622
# Epoch 5/10
# 1719/1719 [==============================] - 1s 730us/step - loss: 0.3752 - accuracy: 0.8656 - val_loss: 0.3771 - val_accuracy: 0.8672
# Epoch 6/10
# 1719/1719 [==============================] - 1s 703us/step - loss: 0.3591 - accuracy: 0.8707 - val_loss: 0.3836 - val_accuracy: 0.8642
# Epoch 7/10
# 1719/1719 [==============================] - 1s 716us/step - loss: 0.3478 - accuracy: 0.8744 - val_loss: 0.3633 - val_accuracy: 0.8698
# Epoch 8/10
# 1719/1719 [==============================] - 1s 700us/step - loss: 0.3369 - accuracy: 0.8784 - val_loss: 0.3546 - val_accuracy: 0.8710
# Epoch 9/10
# 1719/1719 [==============================] - 1s 701us/step - loss: 0.3267 - accuracy: 0.8814 - val_loss: 0.3403 - val_accuracy: 0.8750
# Epoch 10/10
# 1719/1719 [==============================] - 1s 700us/step - loss: 0.3172 - accuracy: 0.8849 - val_loss: 0.3460 - val_accuracy: 0.8732

# %%
# extra code – this cell plots piecewise constant scheduling

boundaries = [50_000, 80_000]
values = [0.01, 0.005, 0.001]

steps = np.arange(100_000)

lrs = np.full(len(steps), values[0])
for boundary, value in zip(boundaries, values[1:]):
    lrs[boundary:] = value

plt.plot(steps, lrs, "-")
plt.axis([0, steps.max(), 0, 0.0105])
plt.xlabel("Step")
plt.ylabel("Learning Rate")
plt.title("Piecewise Constant Scheduling", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# Just like we did with exponential scheduling, we could also implement piecewise constant scheduling manually:

# %%
def piecewise_constant_fn(epoch):
    if epoch < 5:
        return 0.01
    elif epoch < 15:
        return 0.005
    else:
        return 0.001

# %%
# Bardziej ogólny sposób definiowania harmonogramowania stałoprzecinkowego na podstawie części.

# extra code – this cell demonstrates a more general way to define
#              piecewise constant scheduling.

def piecewise_constant(boundaries, values):
    boundaries = np.array([0] + boundaries)
    values = np.array(values)
    def piecewise_constant_fn(epoch):
        return values[(boundaries > epoch).argmax() - 1]
    return piecewise_constant_fn

piecewise_constant_fn = piecewise_constant([5, 15], [0.01, 0.005, 0.001])

# %%
# extra code – use a tf.keras.callbacks.LearningRateScheduler like earlier

n_epochs = 25

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(piecewise_constant_fn)

model = build_model()
optimizer = tf.keras.optimizers.Nadam(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Nadam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Nadam`.
# Epoch 1/25
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.5470 - accuracy: 0.8062 - val_loss: 0.4663 - val_accuracy: 0.8296 - lr: 0.0100
# Epoch 2/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4504 - accuracy: 0.8408 - val_loss: 0.4886 - val_accuracy: 0.8348 - lr: 0.0100
# Epoch 3/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4401 - accuracy: 0.8448 - val_loss: 0.4448 - val_accuracy: 0.8434 - lr: 0.0100
# Epoch 4/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4248 - accuracy: 0.8500 - val_loss: 0.4485 - val_accuracy: 0.8354 - lr: 0.0100
# Epoch 5/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4195 - accuracy: 0.8523 - val_loss: 0.4217 - val_accuracy: 0.8488 - lr: 0.0100
# Epoch 6/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3603 - accuracy: 0.8688 - val_loss: 0.3851 - val_accuracy: 0.8634 - lr: 0.0050
# Epoch 7/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3531 - accuracy: 0.8721 - val_loss: 0.4057 - val_accuracy: 0.8584 - lr: 0.0050
# Epoch 8/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3473 - accuracy: 0.8732 - val_loss: 0.3944 - val_accuracy: 0.8598 - lr: 0.0050
# Epoch 9/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3433 - accuracy: 0.8751 - val_loss: 0.4016 - val_accuracy: 0.8556 - lr: 0.0050
# Epoch 10/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3375 - accuracy: 0.8771 - val_loss: 0.3949 - val_accuracy: 0.8662 - lr: 0.0050
# Epoch 11/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3363 - accuracy: 0.8780 - val_loss: 0.3791 - val_accuracy: 0.8750 - lr: 0.0050
# Epoch 12/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3308 - accuracy: 0.8780 - val_loss: 0.4091 - val_accuracy: 0.8614 - lr: 0.0050
# Epoch 13/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3275 - accuracy: 0.8804 - val_loss: 0.3996 - val_accuracy: 0.8680 - lr: 0.0050
# Epoch 14/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3265 - accuracy: 0.8812 - val_loss: 0.3789 - val_accuracy: 0.8724 - lr: 0.0050
# Epoch 15/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3217 - accuracy: 0.8824 - val_loss: 0.3913 - val_accuracy: 0.8658 - lr: 0.0050
# Epoch 16/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2861 - accuracy: 0.8938 - val_loss: 0.3601 - val_accuracy: 0.8782 - lr: 0.0010
# Epoch 17/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2780 - accuracy: 0.8960 - val_loss: 0.3669 - val_accuracy: 0.8784 - lr: 0.0010
# Epoch 18/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2739 - accuracy: 0.8969 - val_loss: 0.3673 - val_accuracy: 0.8796 - lr: 0.0010
# Epoch 19/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2714 - accuracy: 0.8980 - val_loss: 0.3784 - val_accuracy: 0.8776 - lr: 0.0010
# Epoch 20/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2687 - accuracy: 0.8984 - val_loss: 0.3955 - val_accuracy: 0.8778 - lr: 0.0010
# Epoch 21/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2669 - accuracy: 0.9002 - val_loss: 0.3905 - val_accuracy: 0.8800 - lr: 0.0010
# Epoch 22/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2652 - accuracy: 0.9007 - val_loss: 0.4189 - val_accuracy: 0.8790 - lr: 0.0010
# Epoch 23/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2635 - accuracy: 0.9014 - val_loss: 0.4166 - val_accuracy: 0.8778 - lr: 0.0010
# Epoch 24/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2619 - accuracy: 0.9003 - val_loss: 0.3998 - val_accuracy: 0.8768 - lr: 0.0010
# Epoch 25/25
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2598 - accuracy: 0.9019 - val_loss: 0.4180 - val_accuracy: 0.8770 - lr: 0.0010

# %% [markdown]
# We've looked at `InverseTimeDecay`, `ExponentialDecay`, and `PiecewiseConstantDecay`. A few more schedulers are available in `tf.keras.optimizers.schedules`, here is the full list:

# %%
for name in sorted(dir(tf.keras.optimizers.schedules)):
    if name[0] == name[0].lower():  # must start with capital letter
        continue
    scheduler_class = getattr(tf.keras.optimizers.schedules, name)
    print(f"• {name} – {scheduler_class.__doc__.splitlines()[0]}")
# Out:
# • CosineDecay – A LearningRateSchedule that uses a cosine decay with optional warmup.
# • CosineDecayRestarts – A LearningRateSchedule that uses a cosine decay schedule with restarts.
# • ExponentialDecay – A LearningRateSchedule that uses an exponential decay schedule.
# • InverseTimeDecay – A LearningRateSchedule that uses an inverse time decay schedule.
# • LearningRateSchedule – The learning rate schedule base class.
# • PiecewiseConstantDecay – A LearningRateSchedule that uses a piecewise constant decay schedule.
# • PolynomialDecay – A LearningRateSchedule that uses a polynomial decay schedule.

# %% [markdown]
# ### Performance Scheduling

# %%
## 43 Harmonogramowanie wydajnościowe

# extra code – build and compile the model

model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 [==============================] - 1s 717us/step - loss: 0.6763 - accuracy: 0.7658 - val_loss: 0.4729 - val_accuracy: 0.8356 - lr: 0.0100
# Epoch 2/25
# 1719/1719 [==============================] - 1s 642us/step - loss: 0.4652 - accuracy: 0.8363 - val_loss: 0.4455 - val_accuracy: 0.8404 - lr: 0.0100
# Epoch 3/25
# 1719/1719 [==============================] - 1s 640us/step - loss: 0.4208 - accuracy: 0.8507 - val_loss: 0.4207 - val_accuracy: 0.8502 - lr: 0.0100
# Epoch 4/25
# 1719/1719 [==============================] - 1s 635us/step - loss: 0.3970 - accuracy: 0.8602 - val_loss: 0.3812 - val_accuracy: 0.8620 - lr: 0.0100
# Epoch 5/25
# 1719/1719 [==============================] - 1s 636us/step - loss: 0.3767 - accuracy: 0.8670 - val_loss: 0.3821 - val_accuracy: 0.8642 - lr: 0.0100
# Epoch 6/25
# 1719/1719 [==============================] - 1s 632us/step - loss: 0.3604 - accuracy: 0.8713 - val_loss: 0.3910 - val_accuracy: 0.8644 - lr: 0.0100
# Epoch 7/25
# 1719/1719 [==============================] - 1s 632us/step - loss: 0.3481 - accuracy: 0.8740 - val_loss: 0.3629 - val_accuracy: 0.8718 - lr: 0.0100
# Epoch 8/25
# 1719/1719 [==============================] - 1s 653us/step - loss: 0.3361 - accuracy: 0.8789 - val_loss: 0.3671 - val_accuracy: 0.8644 - lr: 0.0100
# Epoch 9/25
# 1719/1719 [==============================] - 1s 651us/step - loss: 0.3253 - accuracy: 0.8841 - val_loss: 0.3442 - val_accuracy: 0.8770 - lr: 0.0100
# Epoch 10/25
# 1719/1719 [==============================] - 1s 645us/step - loss: 0.3158 - accuracy: 0.8859 - val_loss: 0.3511 - val_accuracy: 0.8730 - lr: 0.0100
# Epoch 11/25
# 1719/1719 [==============================] - 1s 670us/step - loss: 0.3082 - accuracy: 0.8881 - val_loss: 0.3560 - val_accuracy: 0.8700 - lr: 0.0100
# Epoch 12/25
# 1719/1719 [==============================] - 1s 650us/step - loss: 0.3001 - accuracy: 0.8895 - val_loss: 0.3404 - val_accuracy: 0.8726 - lr: 0.0100
# Epoch 13/25
# 1719/1719 [==============================] - 1s 639us/step - loss: 0.2939 - accuracy: 0.8936 - val_loss: 0.3241 - val_accuracy: 0.8790 - lr: 0.0100
# Epoch 14/25
# 1719/1719 [==============================] - 1s 660us/step - loss: 0.2865 - accuracy: 0.8963 - val_loss: 0.3480 - val_accuracy: 0.8750 - lr: 0.0100
# Epoch 15/25
# 1719/1719 [==============================] - 1s 650us/step - loss: 0.2816 - accuracy: 0.8970 - val_loss: 0.3551 - val_accuracy: 0.8742 - lr: 0.0100
# Epoch 16/25
# 1719/1719 [==============================] - 1s 641us/step - loss: 0.2751 - accuracy: 0.8999 - val_loss: 0.3402 - val_accuracy: 0.8758 - lr: 0.0100
# Epoch 17/25
# 1719/1719 [==============================] - 1s 634us/step - loss: 0.2704 - accuracy: 0.9003 - val_loss: 0.3323 - val_accuracy: 0.8774 - lr: 0.0100
# Epoch 18/25
# 1719/1719 [==============================] - 1s 648us/step - loss: 0.2649 - accuracy: 0.9027 - val_loss: 0.3333 - val_accuracy: 0.8778 - lr: 0.0100
# Epoch 19/25
# 1719/1719 [==============================] - 1s 639us/step - loss: 0.2470 - accuracy: 0.9100 - val_loss: 0.3243 - val_accuracy: 0.8788 - lr: 0.0050
# Epoch 20/25
# 1719/1719 [==============================] - 1s 637us/step - loss: 0.2434 - accuracy: 0.9109 - val_loss: 0.3208 - val_accuracy: 0.8824 - lr: 0.0050
# Epoch 21/25
# 1719/1719 [==============================] - 1s 628us/step - loss: 0.2409 - accuracy: 0.9120 - val_loss: 0.3155 - val_accuracy: 0.8812 - lr: 0.0050
# Epoch 22/25
# 1719/1719 [==============================] - 1s 658us/step - loss: 0.2377 - accuracy: 0.9135 - val_loss: 0.3212 - val_accuracy: 0.8810 - lr: 0.0050
# Epoch 23/25
# 1719/1719 [==============================] - 1s 669us/step - loss: 0.2355 - accuracy: 0.9145 - val_loss: 0.3285 - val_accuracy: 0.8822 - lr: 0.0050
# Epoch 24/25
# 1719/1719 [==============================] - 1s 638us/step - loss: 0.2324 - accuracy: 0.9159 - val_loss: 0.3228 - val_accuracy: 0.8818 - lr: 0.0050
# Epoch 25/25
# 1719/1719 [==============================] - 1s 649us/step - loss: 0.2304 - accuracy: 0.9147 - val_loss: 0.3227 - val_accuracy: 0.8852 - lr: 0.0050

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# extra code – this cell plots performance scheduling

# plt.plot(history.epoch, history.history["learning_rate"], "bo-")
# plt.xlabel("Epoch")
# plt.ylabel("Learning Rate", color='b')
# plt.tick_params('y', colors='b')
# plt.gca().set_xlim(0, n_epochs - 1)
# plt.grid(True)

# ax2 = plt.gca().twinx()
# ax2.plot(history.epoch, history.history["val_loss"], "r^-")
# ax2.set_ylabel('Validation Loss', color='r')
# ax2.tick_params('y', colors='r')

# plt.title("Reduce LR on Plateau", fontsize=14)
# plt.show()

# %% [markdown]
# ### 1Cycle scheduling

# %% [markdown]
# The `ExponentialLearningRate` custom callback updates the learning rate during training, at the end of each batch. It multiplies it by a constant `factor`. It also saves the learning rate and loss at each batch. Since `logs["loss"]` is actually the mean loss since the start of the epoch, and we want to save the batch loss instead, we must compute the mean times the number of batches since the beginning of the epoch to get the total loss so far, then we subtract the total loss at the previous batch to get the current batch's loss.

# %%
## 44 Harmonogramowanie 1cycle

K = tf.keras.backend

class ExponentialLearningRate(tf.keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []

    def on_epoch_begin(self, epoch, logs=None):
        self.sum_of_epoch_losses = 0

    def on_batch_end(self, batch, logs=None):
        mean_epoch_loss = logs["loss"]  # the epoch's mean loss so far 
        new_sum_of_epoch_losses = mean_epoch_loss * (batch + 1)
        batch_loss = new_sum_of_epoch_losses - self.sum_of_epoch_losses
        self.sum_of_epoch_losses = new_sum_of_epoch_losses
        lr = self.model.optimizer.learning_rate.numpy()
        self.rates.append(lr)
        self.losses.append(batch_loss)
        self.model.optimizer.learning_rate = lr * self.factor

# %% [markdown]
# The `find_learning_rate()` function trains the model using the `ExponentialLearningRate` callback, and it returns the learning rates and corresponding batch losses. At the end, it restores the model and its optimizer to their initial state.

# %%
def find_learning_rate(model, X, y, epochs=1, batch_size=32, min_rate=1e-4,
                       max_rate=1):
    init_weights = model.get_weights()
    iterations = math.ceil(len(X) / batch_size) * epochs
    factor = (max_rate / min_rate) ** (1 / iterations)
    init_lr = K.get_value(model.optimizer.learning_rate)
    model.optimizer.learning_rate = min_rate
    exp_lr = ExponentialLearningRate(factor)
    history = model.fit(X, y, epochs=epochs, batch_size=batch_size,
                        callbacks=[exp_lr])
    model.optimizer.learning_rate = init_lr
    model.set_weights(init_weights)
    return exp_lr.rates, exp_lr.losses

# %% [markdown]
# The `plot_lr_vs_loss()` function plots the learning rates vs the losses. The optimal learning rate to use as the maximum learning rate in 1cycle is near the bottom of the curve.

# %%
def plot_lr_vs_loss(rates, losses):
    plt.plot(rates, losses, "b")
    plt.gca().set_xscale('log')
    max_loss = losses[0] + min(losses)
    plt.hlines(min(losses), min(rates), max(rates), color="k")
    plt.axis([min(rates), max(rates), 0, max_loss])
    plt.xlabel("Learning rate")
    plt.ylabel("Loss")
    plt.grid()

# %% [markdown]
# Let's build a simple Fashion MNIST model and compile it:

# %%
model = build_model()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %% [markdown]
# Now let's find the optimal max learning rate for 1cycle:

# %%
batch_size = 128
rates, losses = find_learning_rate(model, X_train, y_train, epochs=1,
                                   batch_size=batch_size)
plot_lr_vs_loss(rates, losses)
# Out:
# 430/430 [==============================] - 1s 1ms/step - loss: 1.7344 - accuracy: 0.3895

# %% [markdown]
# Looks like the max learning rate to use for 1cycle is around 10<sup>–1</sup>.

# %% [markdown]
# The `OneCycleScheduler` custom callback updates the learning rate at the beginning of each batch. It applies the logic described in the book: increase the learning rate linearly during about half of training, then reduce it linearly back to the initial learning rate, and lastly reduce it down to close to zero linearly for the very last part of training.

# %%
class OneCycleScheduler(tf.keras.callbacks.Callback):
    def __init__(self, iterations, max_lr=1e-3, start_lr=None,
                 last_iterations=None, last_lr=None):
        self.iterations = iterations
        self.max_lr = max_lr
        self.start_lr = start_lr or max_lr / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_lr = last_lr or self.start_lr / 1000
        self.iteration = 0

    def _interpolate(self, iter1, iter2, lr1, lr2):
        return (lr2 - lr1) * (self.iteration - iter1) / (iter2 - iter1) + lr1

    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            lr = self._interpolate(0, self.half_iteration, self.start_lr,
                                   self.max_lr)
        elif self.iteration < 2 * self.half_iteration:
            lr = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                   self.max_lr, self.start_lr)
        else:
            lr = self._interpolate(2 * self.half_iteration, self.iterations,
                                   self.start_lr, self.last_lr)
        self.iteration += 1
        self.model.optimizer.learning_rate = lr

# %% [markdown]
# Let's build and compile a simple Fashion MNIST model, then train it using the `OneCycleScheduler` callback:

# %%
## 45 Użycie harmonogramowania 1cycle

model = build_model()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["accuracy"])
n_epochs = 25
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * n_epochs,
                             max_lr=0.1)
history = model.fit(X_train, y_train, epochs=n_epochs, batch_size=batch_size,
                    validation_data=(X_valid, y_valid),
                    callbacks=[onecycle])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Epoch 1/25
# 430/430 [==============================] - 1s 1ms/step - loss: 0.9895 - accuracy: 0.6876 - val_loss: 0.5953 - val_accuracy: 0.8072
# Epoch 2/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.5695 - accuracy: 0.8034 - val_loss: 0.5015 - val_accuracy: 0.8302
# Epoch 3/25
# 430/430 [==============================] - 1s 1ms/step - loss: 0.5003 - accuracy: 0.8253 - val_loss: 0.4633 - val_accuracy: 0.8340
# Epoch 4/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.4541 - accuracy: 0.8396 - val_loss: 0.4441 - val_accuracy: 0.8378
# Epoch 5/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.4242 - accuracy: 0.8485 - val_loss: 0.4220 - val_accuracy: 0.8440
# Epoch 6/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.3982 - accuracy: 0.8583 - val_loss: 0.5178 - val_accuracy: 0.8052
# Epoch 7/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.3811 - accuracy: 0.8625 - val_loss: 0.4304 - val_accuracy: 0.8402
# Epoch 8/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.3667 - accuracy: 0.8671 - val_loss: 0.4215 - val_accuracy: 0.8460
# Epoch 9/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.8714 - val_loss: 0.4262 - val_accuracy: 0.8508
# Epoch 10/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.3388 - accuracy: 0.8767 - val_loss: 0.5193 - val_accuracy: 0.8366
# Epoch 11/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.3287 - accuracy: 0.8787 - val_loss: 0.4267 - val_accuracy: 0.8354
# Epoch 12/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.3177 - accuracy: 0.8828 - val_loss: 0.3590 - val_accuracy: 0.8652
# Epoch 13/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.3010 - accuracy: 0.8898 - val_loss: 0.3289 - val_accuracy: 0.8740
# Epoch 14/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2846 - accuracy: 0.8948 - val_loss: 0.3554 - val_accuracy: 0.8756
# Epoch 15/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2711 - accuracy: 0.8993 - val_loss: 0.3254 - val_accuracy: 0.8832
# Epoch 16/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2606 - accuracy: 0.9036 - val_loss: 0.3248 - val_accuracy: 0.8802
# Epoch 17/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2517 - accuracy: 0.9073 - val_loss: 0.3082 - val_accuracy: 0.8874
# Epoch 18/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2409 - accuracy: 0.9107 - val_loss: 0.3133 - val_accuracy: 0.8832
# Epoch 19/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2333 - accuracy: 0.9140 - val_loss: 0.3087 - val_accuracy: 0.8818
# Epoch 20/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2252 - accuracy: 0.9175 - val_loss: 0.3083 - val_accuracy: 0.8850
# Epoch 21/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2182 - accuracy: 0.9199 - val_loss: 0.3050 - val_accuracy: 0.8862
# Epoch 22/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2121 - accuracy: 0.9227 - val_loss: 0.3044 - val_accuracy: 0.8882
# Epoch 23/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2068 - accuracy: 0.9253 - val_loss: 0.3034 - val_accuracy: 0.8858
# Epoch 24/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2042 - accuracy: 0.9255 - val_loss: 0.3036 - val_accuracy: 0.8902
# Epoch 25/25
# 430/430 [==============================] - 0s 1ms/step - loss: 0.2018 - accuracy: 0.9265 - val_loss: 0.3024 - val_accuracy: 0.8894

# %% [markdown]
# # Avoiding Overfitting Through Regularization

# %% [markdown]
# ## $\ell_1$ and $\ell_2$ regularization

# %%
#---tutajn stop---
layer = tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal",
                              kernel_regularizer=tf.keras.regularizers.l2(0.01))

# %% [markdown]
# Or use `l1(0.1)` for ℓ<sub>1</sub> regularization with a factor of 0.1, or `l1_l2(0.1, 0.01)` for both ℓ<sub>1</sub> and ℓ<sub>2</sub> regularization, with factors 0.1 and 0.01 respectively.

# %%
tf.random.set_seed(42)  # extra code – for reproducibility

# %%
from functools import partial

RegularizedDense = partial(tf.keras.layers.Dense,
                           activation="relu",
                           kernel_initializer="he_normal",
                           kernel_regularizer=tf.keras.regularizers.l2(0.01))

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    RegularizedDense(100),
    RegularizedDense(100),
    RegularizedDense(10, activation="softmax",
                     kernel_initializer="glorot_normal")  # not in the book
])

# %%
# extra code – compile and train the model
optimizer = tf.keras.optimizers.SGD(learning_rate=0.02)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=2,
                    validation_data=(X_valid, y_valid))
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Epoch 1/2
# 1719/1719 [==============================] - 1s 689us/step - loss: 3.1299 - accuracy: 0.7686 - val_loss: 1.8595 - val_accuracy: 0.8216
# Epoch 2/2
# 1719/1719 [==============================] - 1s 694us/step - loss: 1.4260 - accuracy: 0.8144 - val_loss: 1.1272 - val_accuracy: 0.8188

# %% [markdown]
# ## Dropout

# %%
tf.random.set_seed(42)  # extra code – for reproducibility

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
# extra code – compile and train the model
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Epoch 1/10
# 1719/1719 [==============================] - 2s 866us/step - loss: 0.6771 - accuracy: 0.7517 - val_loss: 0.4540 - val_accuracy: 0.8368
# Epoch 2/10
# 1719/1719 [==============================] - 1s 810us/step - loss: 0.5126 - accuracy: 0.8126 - val_loss: 0.4134 - val_accuracy: 0.8444
# Epoch 3/10
# 1719/1719 [==============================] - 1s 808us/step - loss: 0.4742 - accuracy: 0.8266 - val_loss: 0.3918 - val_accuracy: 0.8528
# Epoch 4/10
# 1719/1719 [==============================] - 1s 808us/step - loss: 0.4493 - accuracy: 0.8345 - val_loss: 0.3798 - val_accuracy: 0.8626
# Epoch 5/10
# 1719/1719 [==============================] - 1s 809us/step - loss: 0.4328 - accuracy: 0.8399 - val_loss: 0.3687 - val_accuracy: 0.8576
# Epoch 6/10
# 1719/1719 [==============================] - 1s 814us/step - loss: 0.4259 - accuracy: 0.8428 - val_loss: 0.3603 - val_accuracy: 0.8676
# Epoch 7/10
# 1719/1719 [==============================] - 1s 826us/step - loss: 0.4126 - accuracy: 0.8487 - val_loss: 0.3672 - val_accuracy: 0.8634
# Epoch 8/10
# 1719/1719 [==============================] - 1s 809us/step - loss: 0.4082 - accuracy: 0.8498 - val_loss: 0.3454 - val_accuracy: 0.8708
# Epoch 9/10
# 1719/1719 [==============================] - 1s 810us/step - loss: 0.4032 - accuracy: 0.8498 - val_loss: 0.3448 - val_accuracy: 0.8730
# Epoch 10/10
# 1719/1719 [==============================] - 1s 816us/step - loss: 0.3925 - accuracy: 0.8561 - val_loss: 0.3477 - val_accuracy: 0.8706

# %% [markdown]
# The training accuracy looks like it's lower than the validation accuracy, but that's just because dropout is only active during training. If we evaluate the model on the training set after training (i.e., with dropout turned off), we get the "real" training accuracy, which is very slightly higher than the validation accuracy and the test accuracy:

# %%
model.evaluate(X_train, y_train)
# Out:
# 1719/1719 [==============================] - 1s 389us/step - loss: 0.3140 - accuracy: 0.8818
# [0.3139785826206207, 0.8818363547325134]

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 407us/step - loss: 0.3707 - accuracy: 0.8651
# [0.37070316076278687, 0.8651000261306763]

# %% [markdown]
# **Note**: make sure to use `AlphaDropout` instead of `Dropout` if you want to build a self-normalizing neural net using SELU.

# %% [markdown]
# ## MC Dropout

# %%
tf.random.set_seed(42)  # extra code – for reproducibility

# %%
y_probas = np.stack([model(X_test, training=True)
                     for sample in range(100)])
y_proba = y_probas.mean(axis=0)

# %%
model.predict(X_test[:1]).round(3)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# array([[0.   , 0.   , 0.   , 0.   , 0.   , 0.006, 0.   , 0.196, 0.   ,
#         0.798]], dtype=float32)

# %%
y_proba[0].round(3)
# Out:
# array([0.   , 0.   , 0.   , 0.   , 0.   , 0.048, 0.   , 0.28 , 0.001,
#        0.67 ], dtype=float32)

# %%
y_std = y_probas.std(axis=0)
y_std[0].round(3)
# Out:
# array([0.   , 0.   , 0.   , 0.001, 0.   , 0.103, 0.   , 0.18 , 0.006,
#        0.21 ], dtype=float32)

# %%
y_pred = y_proba.argmax(axis=1)
accuracy = (y_pred == y_test).sum() / len(y_test)
accuracy
# Out:
# 0.8659

# %%
class MCDropout(tf.keras.layers.Dropout):
    def call(self, inputs, training=None):
        return super().call(inputs, training=True)

# %%
# extra code – shows how to convert Dropout to MCDropout in a Sequential model
Dropout = tf.keras.layers.Dropout
mc_model = tf.keras.Sequential([
    MCDropout(layer.rate) if isinstance(layer, Dropout) else layer
    for layer in model.layers
])
mc_model.set_weights(model.get_weights())

# %%
mc_model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_22 (Flatten)        (None, 784)               0
#
#  mc_dropout (MCDropout)      (None, 784)               0
#
#  dense_89 (Dense)            (None, 100)               78500
#
#  mc_dropout_1 (MCDropout)    (None, 100)               0
#
#  dense_90 (Dense)            (None, 100)               10100
#
#  mc_dropout_2 (MCDropout)    (None, 100)               0
#
#  dense_91 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 89610 (350.04 KB)
# Trainable params: 89610 (350.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Now we can use the model with MC Dropout:

# %%
# extra code – shows that the model works without retraining
tf.random.set_seed(42)
np.mean([mc_model.predict(X_test[:1])
         for sample in range(100)], axis=0).round(2)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# array([[0.  , 0.  , 0.  , 0.  , 0.  , 0.04, 0.  , 0.31, 0.  , 0.64]],
#       dtype=float32)

# %% [markdown]
# ## Max norm

# %%
dense = tf.keras.layers.Dense(
    100, activation="relu", kernel_initializer="he_normal",
    kernel_constraint=tf.keras.constraints.max_norm(1.))

# %%
# extra code – shows how to apply max norm to every hidden layer in a model

MaxNormDense = partial(tf.keras.layers.Dense,
                       activation="relu", kernel_initializer="he_normal",
                       kernel_constraint=tf.keras.constraints.max_norm(1.))

tf.random.set_seed(42)
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    MaxNormDense(100),
    MaxNormDense(100),
    tf.keras.layers.Dense(10, activation="softmax")
])
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# Epoch 1/10
# 1719/1719 [==============================] - 2s 982us/step - loss: 0.5467 - accuracy: 0.8035 - val_loss: 0.4316 - val_accuracy: 0.8380
# Epoch 2/10
# 1719/1719 [==============================] - 2s 928us/step - loss: 0.4123 - accuracy: 0.8495 - val_loss: 0.4122 - val_accuracy: 0.8424
# Epoch 3/10
# 1719/1719 [==============================] - 2s 934us/step - loss: 0.3798 - accuracy: 0.8597 - val_loss: 0.3755 - val_accuracy: 0.8632
# Epoch 4/10
# 1719/1719 [==============================] - 2s 952us/step - loss: 0.3600 - accuracy: 0.8679 - val_loss: 0.3529 - val_accuracy: 0.8678
# Epoch 5/10
# 1719/1719 [==============================] - 2s 950us/step - loss: 0.3476 - accuracy: 0.8708 - val_loss: 0.3554 - val_accuracy: 0.8656
# Epoch 6/10
# 1719/1719 [==============================] - 1s 857us/step - loss: 0.3415 - accuracy: 0.8739 - val_loss: 0.3999 - val_accuracy: 0.8556
# Epoch 7/10
# 1719/1719 [==============================] - 1s 849us/step - loss: 0.3317 - accuracy: 0.8763 - val_loss: 0.3922 - val_accuracy: 0.8560
# Epoch 8/10
# 1719/1719 [==============================] - 2s 923us/step - loss: 0.3270 - accuracy: 0.8776 - val_loss: 0.3433 - val_accuracy: 0.8728
# Epoch 9/10
# 1719/1719 [==============================] - 2s 922us/step - loss: 0.3281 - accuracy: 0.8780 - val_loss: 0.3787 - val_accuracy: 0.8548
# Epoch 10/10
# 1719/1719 [==============================] - 2s 951us/step - loss: 0.3200 - accuracy: 0.8805 - val_loss: 0.4010 - val_accuracy: 0.8544

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1. to 7.

# %% [markdown]
# 1. Glorot initialization and He initialization were designed to make the output standard deviation as close as possible to the input standard deviation, at least at the beginning of training. This reduces the vanishing/exploding gradients problem.
# 2. No, all weights should be sampled independently; they should not all have the same initial value. One important goal of sampling weights randomly is to break symmetry: if all the weights have the same initial value, even if that value is not zero, then symmetry is not broken (i.e., all neurons in a given layer are equivalent), and backpropagation will be unable to break it. Concretely, this means that all the neurons in any given layer will always have the same weights. It's like having just one neuron per layer, and much slower. It is virtually impossible for such a configuration to converge to a good solution.
# 3. It is perfectly fine to initialize the bias terms to zero. Some people like to initialize them just like weights, and that's OK too; it does not make much difference.
# 4. ReLU is usually a good default for the hidden layers, as it is fast and yields good results. Its ability to output precisely zero can also be useful in some cases (e.g., see Chapter 17). Moreover, it can sometimes benefit from optimized implementations as well as from hardware acceleration. The leaky ReLU variants of ReLU can improve the model's quality without hindering its speed too much compared to ReLU. For large neural nets and more complex problems, GLU, Swish and Mish can give you a slightly higher quality model, but they have a computational cost. The hyperbolic tangent (tanh) can be useful in the output layer if you need to output a number in a fixed range (by default between –1 and 1), but nowadays it is not used much in hidden layers, except in recurrent nets. The sigmoid activation function is also useful in the output layer when you need to estimate a probability (e.g., for binary classification), but it is rarely used in hidden layers (there are exceptions—for example, for the coding layer of variational autoencoders; see Chapter 17). The softplus activation function is useful in the output layer when you need to ensure that the output will always be positive. The softmax activation function is useful in the output layer to estimate probabilities for mutually exclusive classes, but it is rarely (if ever) used in hidden layers.
# 5. If you set the `momentum` hyperparameter too close to 1 (e.g., 0.99999) when using an `SGD` optimizer, then the algorithm will likely pick up a lot of speed, hopefully moving roughly toward the global minimum, but its momentum will carry it right past the minimum. Then it will slow down and come back, accelerate again, overshoot again, and so on. It may oscillate this way many times before converging, so overall it will take much longer to converge than with a smaller `momentum` value.
# 6. One way to produce a sparse model (i.e., with most weights equal to zero) is to train the model normally, then zero out tiny weights. For more sparsity, you can apply ℓ<sub>1</sub> regularization during training, which pushes the optimizer toward sparsity. A third option is to use the TensorFlow Model Optimization Toolkit.
# 7. Yes, dropout does slow down training, in general roughly by a factor of two. However, it has no impact on inference speed since it is only turned on during training. MC Dropout is exactly like dropout during training, but it is still active during inference, so each inference is slowed down slightly. More importantly, when using MC Dropout you generally want to run inference 10 times or more to get better predictions. This means that making predictions is slowed down by a factor of 10 or more.

# %% [markdown]
# ## 8. Deep Learning on CIFAR10

# %% [markdown]
# ### a.
# *Exercise: Build a DNN with 20 hidden layers of 100 neurons each (that's too many, but it's the point of this exercise). Use He initialization and the Swish activation function.*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    activation="swish",
                                    kernel_initializer="he_normal"))

# %% [markdown]
# ### b.
# *Exercise: Using Nadam optimization and early stopping, train the network on the CIFAR10 dataset. You can load it with `tf.keras.datasets.cifar10.load_data()`. The dataset is composed of 60,000 32 × 32–pixel color images (50,000 for training, 10,000 for testing) with 10 classes, so you'll need a softmax output layer with 10 neurons. Remember to search for the right learning rate each time you change the model's architecture or hyperparameters.*

# %% [markdown]
# Let's add the output layer to the model:

# %%
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %% [markdown]
# Let's use a Nadam optimizer with a learning rate of 5e-5. I tried learning rates 1e-5, 3e-5, 1e-4, 3e-4, 1e-3, 3e-3 and 1e-2, and I compared their learning curves for 10 epochs each (using the TensorBoard callback, below). The learning rates 3e-5 and 1e-4 were pretty good, so I tried 5e-5, which turned out to be slightly better.

# %%
optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-5)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Nadam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Nadam`.

# %% [markdown]
# Let's load the CIFAR10 dataset. We also want to use early stopping, so we need a validation set. Let's use the first 5,000 images of the original training set as the validation set:

# %%
cifar10 = tf.keras.datasets.cifar10.load_data()
(X_train_full, y_train_full), (X_test, y_test) = cifar10

X_train = X_train_full[5000:]
y_train = y_train_full[5000:]
X_valid = X_train_full[:5000]
y_valid = y_train_full[:5000]

# %% [markdown]
# Now we can create the callbacks we need and train the model:

# %%
# import tensorflow as tf, keras
# print("TF:", tf.__version__)
# print("Keras:", keras.__version__)
# print("tf.keras:", tf.keras.__version__)

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20,
                                                     restore_best_weights=True)
# model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_cifar10_model.keras",
#                                                          save_best_only=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "my_cifar10_model.weights.h5", save_best_only=True, save_weights_only=True
)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./my_cifar10_logs
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# /opt/homebrew/anaconda3/envs/homl3/lib/python3.10/site-packages/tensorboard/default.py:30: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# W0108 14:50:41.219263 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.221786 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.233921 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.237349 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.240794 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.245558 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.258767 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.261454 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.264173 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.277297 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.278750 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:50:41.280689 6254587904 plugin_event_accumulator.py:369] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# Address already in use
# Port 6006 is in use by another program. Either identify and stop that program, or start the server with a different port.

# %%
model.fit(X_train, y_train, epochs=100,
          validation_data=(X_valid, y_valid),
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 1407/1407 [==============================] - 9s 5ms/step - loss: 4.7752 - accuracy: 0.1444 - val_loss: 2.2333 - val_accuracy: 0.1936
# Epoch 2/100
# 1407/1407 [==============================] - 6s 5ms/step - loss: 2.1382 - accuracy: 0.2193 - val_loss: 2.0994 - val_accuracy: 0.2244
# Epoch 3/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 2.0078 - accuracy: 0.2608 - val_loss: 1.9720 - val_accuracy: 0.2752
# Epoch 4/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.9379 - accuracy: 0.2895 - val_loss: 1.9360 - val_accuracy: 0.3052
# Epoch 5/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.8675 - accuracy: 0.3150 - val_loss: 1.8948 - val_accuracy: 0.3066
# Epoch 6/100
# 1407/1407 [==============================] - 6s 5ms/step - loss: 1.8122 - accuracy: 0.3380 - val_loss: 1.8144 - val_accuracy: 0.3342
# Epoch 7/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.7693 - accuracy: 0.3562 - val_loss: 1.7482 - val_accuracy: 0.3642
# Epoch 8/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.7273 - accuracy: 0.3720 - val_loss: 1.7377 - val_accuracy: 0.3758
# Epoch 9/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.6993 - accuracy: 0.3875 - val_loss: 1.6995 - val_accuracy: 0.3820
# Epoch 10/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.6716 - accuracy: 0.3961 - val_loss: 1.6925 - val_accuracy: 0.3826
# Epoch 11/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.6435 - accuracy: 0.4046 - val_loss: 1.7043 - val_accuracy: 0.3822
# Epoch 12/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.6222 - accuracy: 0.4164 - val_loss: 1.6827 - val_accuracy: 0.3974
# Epoch 13/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.6004 - accuracy: 0.4234 - val_loss: 1.6363 - val_accuracy: 0.4180
# Epoch 14/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.5867 - accuracy: 0.4271 - val_loss: 1.6157 - val_accuracy: 0.4252
# Epoch 15/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.5660 - accuracy: 0.4387 - val_loss: 1.6277 - val_accuracy: 0.4174
# Epoch 16/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.5490 - accuracy: 0.4432 - val_loss: 1.6110 - val_accuracy: 0.4190
# Epoch 17/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.5326 - accuracy: 0.4494 - val_loss: 1.6021 - val_accuracy: 0.4270
# Epoch 18/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.5206 - accuracy: 0.4524 - val_loss: 1.5939 - val_accuracy: 0.4294
# Epoch 19/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.5070 - accuracy: 0.4579 - val_loss: 1.5816 - val_accuracy: 0.4290
# Epoch 20/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4964 - accuracy: 0.4625 - val_loss: 1.5902 - val_accuracy: 0.4332
# Epoch 21/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4862 - accuracy: 0.4678 - val_loss: 1.5645 - val_accuracy: 0.4414
# Epoch 22/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4764 - accuracy: 0.4698 - val_loss: 1.5665 - val_accuracy: 0.4400
# Epoch 23/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4604 - accuracy: 0.4766 - val_loss: 1.5705 - val_accuracy: 0.4376
# Epoch 24/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4545 - accuracy: 0.4760 - val_loss: 1.5847 - val_accuracy: 0.4352
# Epoch 25/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4403 - accuracy: 0.4829 - val_loss: 1.5373 - val_accuracy: 0.4530
# Epoch 26/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4334 - accuracy: 0.4838 - val_loss: 1.5859 - val_accuracy: 0.4260
# Epoch 27/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4238 - accuracy: 0.4900 - val_loss: 1.5479 - val_accuracy: 0.4540
# Epoch 28/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4161 - accuracy: 0.4916 - val_loss: 1.5699 - val_accuracy: 0.4370
# Epoch 29/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.4073 - accuracy: 0.4931 - val_loss: 1.5465 - val_accuracy: 0.4490
# Epoch 30/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3964 - accuracy: 0.4996 - val_loss: 1.5427 - val_accuracy: 0.4422
# Epoch 31/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3887 - accuracy: 0.5024 - val_loss: 1.5476 - val_accuracy: 0.4552
# Epoch 32/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3806 - accuracy: 0.5045 - val_loss: 1.5622 - val_accuracy: 0.4472
# Epoch 33/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3713 - accuracy: 0.5077 - val_loss: 1.5346 - val_accuracy: 0.4588
# Epoch 34/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3679 - accuracy: 0.5094 - val_loss: 1.5860 - val_accuracy: 0.4420
# Epoch 35/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3554 - accuracy: 0.5133 - val_loss: 1.5818 - val_accuracy: 0.4452
# Epoch 36/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3486 - accuracy: 0.5160 - val_loss: 1.5546 - val_accuracy: 0.4522
# Epoch 37/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3403 - accuracy: 0.5180 - val_loss: 1.5387 - val_accuracy: 0.4600
# Epoch 38/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3354 - accuracy: 0.5207 - val_loss: 1.5313 - val_accuracy: 0.4648
# Epoch 39/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3261 - accuracy: 0.5243 - val_loss: 1.5666 - val_accuracy: 0.4532
# Epoch 40/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3159 - accuracy: 0.5282 - val_loss: 1.5610 - val_accuracy: 0.4506
# Epoch 41/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3115 - accuracy: 0.5290 - val_loss: 1.5886 - val_accuracy: 0.4474
# Epoch 42/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.3038 - accuracy: 0.5303 - val_loss: 1.5714 - val_accuracy: 0.4568
# Epoch 43/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2980 - accuracy: 0.5357 - val_loss: 1.5423 - val_accuracy: 0.4598
# Epoch 44/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2898 - accuracy: 0.5392 - val_loss: 1.5700 - val_accuracy: 0.4512
# Epoch 45/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2801 - accuracy: 0.5398 - val_loss: 1.5661 - val_accuracy: 0.4546
# Epoch 46/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2781 - accuracy: 0.5420 - val_loss: 1.5489 - val_accuracy: 0.4598
# Epoch 47/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2682 - accuracy: 0.5452 - val_loss: 1.5659 - val_accuracy: 0.4554
# Epoch 48/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2621 - accuracy: 0.5484 - val_loss: 1.5870 - val_accuracy: 0.4500
# Epoch 49/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2561 - accuracy: 0.5494 - val_loss: 1.5627 - val_accuracy: 0.4626
# Epoch 50/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2491 - accuracy: 0.5520 - val_loss: 1.5872 - val_accuracy: 0.4520
# Epoch 51/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2430 - accuracy: 0.5567 - val_loss: 1.6031 - val_accuracy: 0.4500
# Epoch 52/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2327 - accuracy: 0.5572 - val_loss: 1.5915 - val_accuracy: 0.4544
# Epoch 53/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2290 - accuracy: 0.5581 - val_loss: 1.5778 - val_accuracy: 0.4622
# Epoch 54/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2249 - accuracy: 0.5613 - val_loss: 1.5818 - val_accuracy: 0.4472
# Epoch 55/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2129 - accuracy: 0.5652 - val_loss: 1.5886 - val_accuracy: 0.4560
# Epoch 56/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2076 - accuracy: 0.5671 - val_loss: 1.5815 - val_accuracy: 0.4596
# Epoch 57/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.2017 - accuracy: 0.5711 - val_loss: 1.6079 - val_accuracy: 0.4504
# Epoch 58/100
# 1407/1407 [==============================] - 7s 5ms/step - loss: 1.1954 - accuracy: 0.5707 - val_loss: 1.6037 - val_accuracy: 0.4532

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 157/157 [==============================] - 0s 939us/step - loss: 1.5313 - accuracy: 0.4648
# [1.5312610864639282, 0.46480000019073486]

# %% [markdown]
# The model with the lowest validation loss gets about 46.8% accuracy on the validation set. It took 29 epochs to reach the lowest validation loss, with roughly 10 seconds per epoch on my laptop (without a GPU). Let's see if we can improve the model using Batch Normalization.

# %% [markdown]
# ### c.
# *Exercise: Now try adding Batch Normalization and compare the learning curves: Is it converging faster than before? Does it produce a better model? How does it affect training speed?*

# %% [markdown]
# The code below is very similar to the code above, with a few changes:
#
# * I added a BN layer after every Dense layer (before the activation function), except for the output layer.
# * I changed the learning rate to 5e-4. I experimented with 1e-5, 3e-5, 5e-5, 1e-4, 3e-4, 5e-4, 1e-3 and 3e-3, and I chose the one with the best validation performance after 20 epochs.
# * I renamed the run directories to run_bn_* and the model file name to `my_cifar10_bn_model`.

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100, kernel_initializer="he_normal"))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation("swish"))

model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-4)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20,
                                                     restore_best_weights=True)
# model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_cifar10_bn_model.keras",
#                                                          save_best_only=True)
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "my_cifar10_bn_model.h5",
    save_best_only=True
)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_bn_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

model.fit(X_train, y_train, epochs=100,
          validation_data=(X_valid, y_valid),
          callbacks=callbacks)

model.evaluate(X_valid, y_valid)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Nadam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Nadam`.
# Epoch 1/100
#  253/1407 [====>.........................] - ETA: 9s - loss: 2.3399 - accuracy: 0.1429

# %% [markdown]
# * *Is the model converging faster than before?* Much faster! The previous model took 29 epochs to reach the lowest validation loss, while the new model achieved that same loss in just 12 epochs and continued to make progress until the 17th epoch. The BN layers stabilized training and allowed us to use a much larger learning rate, so convergence was faster.
# * *Does BN produce a better model?* Yes! The final model is also much better, with 50.7% validation accuracy instead of 46.7%. It's still not a very good model, but at least it's much better than before (a Convolutional Neural Network would do much better, but that's a different topic, see chapter 14).
# * *How does BN affect training speed?* Although the model converged much faster, each epoch took about 15s instead of 10s, because of the extra computations required by the BN layers. But overall the training time (wall time) to reach the best model was shortened by about 10%.

# %% [markdown]
# ### d.
# *Exercise: Try replacing Batch Normalization with SELU, and make the necessary adjustements to ensure the network self-normalizes (i.e., standardize the input features, use LeCun normal initialization, make sure the DNN contains only a sequence of dense layers, etc.).*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    kernel_initializer="lecun_normal",
                                    activation="selu"))

model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Nadam(learning_rate=7e-4)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience=20, restore_best_weights=True)
# model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
#     "my_cifar10_selu_model.keras", save_best_only=True)

model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "my_cifar10_selu_model.h5",
    save_best_only=True
)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_selu_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

X_means = X_train.mean(axis=0)
X_stds = X_train.std(axis=0)
X_train_scaled = (X_train - X_means) / X_stds
X_valid_scaled = (X_valid - X_means) / X_stds
X_test_scaled = (X_test - X_means) / X_stds

model.fit(X_train_scaled, y_train, epochs=100,
          validation_data=(X_valid_scaled, y_valid),
          callbacks=callbacks)

model.evaluate(X_valid_scaled, y_valid)

# %% [markdown]
# This model reached the first model's validation loss in just 8 epochs. After 14 epochs, it reached its lowest validation loss, with about 50.3% accuracy, which is better than the original model (46.7%), but not quite as good as the model using batch normalization (50.7%). Each epoch took only 9 seconds. So it's the fastest model to train so far.

# %% [markdown]
# ### e.
# *Exercise: Try regularizing the model with alpha dropout. Then, without retraining your model, see if you can achieve better accuracy using MC Dropout.*

# %% [markdown]
# **Warning**: there are now two versions of `AlphaDropout`. One is deprecated and also broken in some recent versions of TF, and unfortunately that's the version in the `tensorflow` library. Luckily, there's a perfectly fine version in the `keras` library (i.e., `keras`, not `tf.keras`). It's neither deprecated nor broken, so let's import and use that one:

# %%
import keras.layers

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    kernel_initializer="lecun_normal",
                                    activation="selu"))

model.add(keras.layers.AlphaDropout(rate=0.1))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Nadam(learning_rate=5e-4)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience=20, restore_best_weights=True)
# model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
#     "my_cifar10_alpha_dropout_model.keras", save_best_only=True)

model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "my_cifar10_alpha_dropout_model.h5",
    save_best_only=True
)
run_index = 1 # increment every time you train the model
run_logdir = Path() / "my_cifar10_logs" / f"run_alpha_dropout_{run_index:03d}"
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)
callbacks = [early_stopping_cb, model_checkpoint_cb, tensorboard_cb]

X_means = X_train.mean(axis=0)
X_stds = X_train.std(axis=0)
X_train_scaled = (X_train - X_means) / X_stds
X_valid_scaled = (X_valid - X_means) / X_stds
X_test_scaled = (X_test - X_means) / X_stds

model.fit(X_train_scaled, y_train, epochs=100,
          validation_data=(X_valid_scaled, y_valid),
          callbacks=callbacks)

model.evaluate(X_valid_scaled, y_valid)

# %% [markdown]
# The model reaches 48.1% accuracy on the validation set. That's worse than without dropout (50.3%). With an extensive hyperparameter search, it might be possible to do better (I tried dropout rates of 5%, 10%, 20% and 40%, and learning rates 1e-4, 3e-4, 5e-4, and 1e-3), but probably not much better in this case.

# %% [markdown]
# Let's use MC Dropout now. We will need the `MCAlphaDropout` class we used earlier, so let's just copy it here for convenience:

# %%
class MCAlphaDropout(keras.layers.AlphaDropout):
    def call(self, inputs):
        return super().call(inputs, training=True)

# %% [markdown]
# Now let's create a new model, identical to the one we just trained (with the same weights), but with `MCAlphaDropout` dropout layers instead of `AlphaDropout` layers:

# %%
mc_model = tf.keras.Sequential([
    (
        MCAlphaDropout(layer.rate)
        if isinstance(layer, keras.layers.AlphaDropout)
        else layer
    )
    for layer in model.layers
])

# %% [markdown]
# Then let's add a couple utility functions. The first will run the model many times (10 by default) and it will return the mean predicted class probabilities. The second will use these mean probabilities to predict the most likely class for each instance:

# %%
def mc_dropout_predict_probas(mc_model, X, n_samples=10):
    Y_probas = [mc_model.predict(X) for sample in range(n_samples)]
    return np.mean(Y_probas, axis=0)

def mc_dropout_predict_classes(mc_model, X, n_samples=10):
    Y_probas = mc_dropout_predict_probas(mc_model, X, n_samples)
    return Y_probas.argmax(axis=1)

# %% [markdown]
# Now let's make predictions for all the instances in the validation set, and compute the accuracy:

# %%
tf.random.set_seed(42)

y_pred = mc_dropout_predict_classes(mc_model, X_valid_scaled)
accuracy = (y_pred == y_valid[:, 0]).mean()
accuracy

# %% [markdown]
# We get back to roughly the accuracy of the model without dropout in this case (about 50.3% accuracy).
#
# So the best model we got in this exercise is the Batch Normalization model.

# %% [markdown]
# ### f.
# *Exercise: Retrain your model using 1cycle scheduling and see if it improves training speed and model accuracy.*

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                    kernel_initializer="lecun_normal",
                                    activation="selu"))

model.add(keras.layers.AlphaDropout(rate=0.1))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.SGD()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

# %%
batch_size = 128
rates, losses = find_learning_rate(model, X_train_scaled, y_train, epochs=1,
                                   batch_size=batch_size)
plot_lr_vs_loss(rates, losses)

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[32, 32, 3]))
for _ in range(20):
    model.add(tf.keras.layers.Dense(100,
                                 kernel_initializer="lecun_normal",
                                 activation="selu"))

model.add(keras.layers.AlphaDropout(rate=0.1))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.SGD(learning_rate=2e-2)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

# %%
n_epochs = 15
n_iterations = math.ceil(len(X_train_scaled) / batch_size) * n_epochs
onecycle = OneCycleScheduler(n_iterations, max_lr=0.05)
history = model.fit(X_train_scaled, y_train, epochs=n_epochs, batch_size=batch_size,
                    validation_data=(X_valid_scaled, y_valid),
                    callbacks=[onecycle])

# %% [markdown]
# One cycle allowed us to train the model in just 15 epochs, each taking only 2 seconds (thanks to the larger batch size). This is several times faster than the fastest model we trained so far. Moreover, we improved the model's performance (from 50.7% to 52.0%).
